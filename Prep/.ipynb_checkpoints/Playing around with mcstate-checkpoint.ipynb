# %%
# Load packages
library(mgcv)
library(ggplot2)
library(tidyverse)
library(lubridate)
library(gridExtra)
library(grid)
library(writexl)
library(magrittr)
#library(rstatix)
# Out:
# Loading required package: nlme
#
# This is mgcv 1.8-40. For overview type 'help("mgcv-package")'.
#
# -- Attaching packages ------------------------------------------------------------------------------- tidyverse 1.3.1 --
#
# v tibble  3.1.7     v dplyr   1.0.9
# v tidyr   1.2.0     v stringr 1.4.0
# v readr   2.1.2     v forcats 0.5.1
# v purrr   0.3.4
#
# -- Conflicts ---------------------------------------------------------------------------------- tidyverse_conflicts() --
# x dplyr::collapse() masks nlme::collapse()
# x dplyr::filter()   masks stats::filter()
# x dplyr::lag()      masks stats::lag()
#
#
# Attaching package: 'lubridate'
#
#
# The following objects are masked from 'package:base':
#
#     date, intersect, setdiff, union
#
#
#
# Attaching package: 'gridExtra'
#
#
# The following object is masked from 'package:dplyr':
#
#     combine
#
#
#
# Attaching package: 'magrittr'
#
#
# The following object is masked from 'package:purrr':
#
#     set_names
#
#
# The following object is masked from 'package:tidyr':
#
#     extract

# %%
PATH <- file.path("C:/Users/julia/OneDrive - London School of Hygiene and Tropical Medicine/Documents/LSHTM/Project") #"/home/andewegs/1_RSV_scripts/"
setwd(PATH)
incidence <- read_csv(file = "Flu_incidence.csv")
# Out:
# Rows: 19 Columns: 3
# -- Column specification ------------------------------------------------------------------------------------------------
# Delimiter: ","
# dbl (3): day, children, adults
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
incidence
# Out:
#    day children adults
# 1   1    35       50
# 2   2    40       70
# 3   3    30      117
# 4   4  1395      467
# 5   5  3000     1096
# 6   6  7064     2734
# 7   7  9382     5021
# 8   8  7583     5501
# 9   9  3760     2753
# 10 10  1982     1844
# 11 11  1054     1189
# 12 12   361      647
# 13 13    73      416
# 14 14    86      152
# 15 15    41      101
# 16 16    38      300
# 17 17    37       91
# 18 18   108      237
# 19 19    73      238

# %%
dt <- 0.25
sir_data <- mcstate::particle_filter_data(data = incidence,
                                          time = "day",
                                          rate = 1 / dt)
rmarkdown::paged_table(sir_data)
# Out:
#    day_start day_end step_start step_end children adults
# 1   0         1       0          4         35       50
# 2   1         2       4          8         40       70
# 3   2         3       8         12         30      117
# 4   3         4      12         16       1395      467
# 5   4         5      16         20       3000     1096
# 6   5         6      20         24       7064     2734
# 7   6         7      24         28       9382     5021
# 8   7         8      28         32       7583     5501
# 9   8         9      32         36       3760     2753
# 10  9        10      36         40       1982     1844
# 11 10        11      40         44       1054     1189
# 12 11        12      44         48        361      647
# 13 12        13      48         52         73      416
# 14 13        14      52         56         86      152
# 15 14        15      56         60         41      101
# 16 15        16      60         64         38      300
# 17 16        17      64         68         37       91
# 18 17        18      68         72        108      237
# 19 18        19      72         76         73      238

# %%
plot(incidence$day, incidence$children,
     type = "l", xlab = "Day", ylab = "New cases in children")
# Out:
# plot without title

# %%
case_compare <- function(state, observed, pars = NULL) {
  exp_noise <- 1e6

  incidence_modelled <- state[5, , drop = TRUE]
  incidence_observed <- observed$children
  lambda <- incidence_modelled +
    rexp(n = length(incidence_modelled), rate = exp_noise)
  dpois(x = incidence_observed, lambda = lambda, log = TRUE)
}

# %%
gen_sir <- dust::dust_example("sir")
gen_sir$new(pars = list(), step = 0, n_particles = 1L)$info()
# Out:
# $vars
# [1] "S"           "I"           "R"           "cases_cumul" "cases_inc"
#
# $pars
# $pars$beta
# [1] 0.2
#
# $pars$gamma
# [1] 0.1

# %%
incidence_compare <- function(state, prev_state, observed, pars = NULL) {
  exp_noise <- 1e6

  lambda <- state[4, , drop = TRUE] +
    rexp(n = length(incidence_modelled), rate = exp_noise)
  dpois(x = observed$children, lambda = lambda, log = TRUE)
}

# %%
n_particles <- 100
filter <- mcstate::particle_filter$new(data = sir_data,
                                       model = gen_sir,
                                       n_particles = n_particles,
                                       compare = case_compare,
                                       seed = 1L)

# %%
filter$run(save_history = TRUE, pars = list(dt = dt))
# Out:
# [1] -152252.8

# %%
plot_particle_filter <- function(history, true_history, times, obs_end = NULL) {
  if (is.null(obs_end)) {
    obs_end <- max(times)
  }

  par(mar = c(4.1, 5.1, 0.5, 0.5), las = 1)
  cols <- c(S = "#8c8cd9", I = "#cc0044", R = "#999966")
  matplot(times, t(history[1, , -1]), type = "l",
          xlab = "Time", ylab = "Number of individuals",
          col = cols[["S"]], lty = 1, ylim = range(history))
  matlines(times, t(history[2, , -1]), col = cols[["I"]], lty = 1)
  matlines(times, t(history[3, , -1]), col = cols[["R"]], lty = 1)
  matpoints(times[1:obs_end], t(true_history[1:3, , -1]), pch = 19,
            col = cols)
  legend("left", lwd = 1, col = cols, legend = names(cols), bty = "n")
}

#true_history <- readRDS("sir_true_history.rds")
plot_particle_filter(filter$history(), true_history, incidence$day)
# Out:
# Error in t(true_history[1:3, , -1]): object 'true_history' not found
# Traceback:
#
# 1. plot_particle_filter(filter$history(), true_history, incidence$day)
# 2. matpoints(times[1:obs_end], t(true_history[1:3, , -1]), pch = 19,
#  .     col = cols)   # at line 13-14 of file <text>
# 3. matplot(x = x, y = y, type = type, lty = lty, lwd = lwd, pch = pch,
#  .     col = col, add = TRUE, ...)
# 4. t(true_history[1:3, , -1])   # at line 13-14 of file <text>
# plot without title

# %%
filter$run(save_history = TRUE, pars = list(dt = dt, beta = 0.4, gamma = 0.2))
# Out:
# [1] -124077.1

# %% [markdown]
# **Inferring parameters**

# %%
beta <- mcstate::pmcmc_parameter("beta", 0.2, min = 0)
gamma <- mcstate::pmcmc_parameter("gamma", 0.1, min = 0, prior = function(p)
  dgamma(p, shape = 1, scale = 0.2, log = TRUE))

proposal_matrix <- diag(0.1, 2)
mcmc_pars <- mcstate::pmcmc_parameters$new(list(beta = beta, gamma = gamma),
                                           proposal_matrix)

# %%
n_steps <- 500
n_burnin <- 200
control <- mcstate::pmcmc_control(
    n_steps,
    save_state = TRUE,
    save_trajectories = TRUE,
    progress = TRUE)
pmcmc_run <- mcstate::pmcmc(mcmc_pars, filter, control = control)
# Out:
# Running chain 1 / 1
#
#
# Step 14 / 500 [>-----------------------------------] ETA  8s | 00:00:00 so far
#
# Step 15 / 500 [>-----------------------------------] ETA  9s | 00:00:00 so far
#
# Step 16 / 500 [>-----------------------------------] ETA  9s | 00:00:00 so far
#
# Step 17 / 500 [>-----------------------------------] ETA 10s | 00:00:00 so far
#
# Step 18 / 500 [>-----------------------------------] ETA 10s | 00:00:00 so far
#
# Step 19 / 500 [>-----------------------------------] ETA 11s | 00:00:00 so far
#
# Step 20 / 500 [>-----------------------------------] ETA 11s | 00:00:00 so far
#
# Step 21 / 500 [=>----------------------------------] ETA 11s | 00:00:00 so far
#
# Step 22 / 500 [=>----------------------------------] ETA 12s | 00:00:00 so far
#
# Step 23 / 500 [=>----------------------------------] ETA 12s | 00:00:00 so far
#
# Step 24 / 500 [=>----------------------------------] ETA 12s | 00:00:00 so far
#
# Step 25 / 500 [=>----------------------------------] ETA 12s | 00:00:00 so far
#
# Step 26 / 500 [=>----------------------------------] ETA 13s | 00:00:00 so far
#
# Step 27 / 500 [=>----------------------------------] ETA 13s | 00:00:00 so far
#
# Step 28 / 500 [=>----------------------------------] ETA 13s | 00:00:00 so far
#
# Step 29 / 500 [=>----------------------------------] ETA 13s | 00:00:00 so far
#
# Step 30 / 500 [=>----------------------------------] ETA 13s | 00:00:00 so far
#
# Step 31 / 500 [=>----------------------------------] ETA 13s | 00:00:00 so far
#
# Step 32 / 500 [=>----------------------------------] ETA 13s | 00:00:00 so far
#
# Step 33 / 500 [=>----------------------------------] ETA 13s | 00:00:00 so far
#
# Step 34 / 500 [=>----------------------------------] ETA 13s | 00:00:00 so far
#
# Step 35 / 500 [==>---------------------------------] ETA 13s | 00:00:00 so far
#
# Step 36 / 500 [==>---------------------------------] ETA 13s | 00:00:01 so far
#
# Step 37 / 500 [==>---------------------------------] ETA 13s | 00:00:01 so far
#
# Step 38 / 500 [==>---------------------------------] ETA 14s | 00:00:01 so far
#
# Step 39 / 500 [==>---------------------------------] ETA 14s | 00:00:01 so far
#
# Step 40 / 500 [==>---------------------------------] ETA 14s | 00:00:01 so far
#
# Step 41 / 500 [==>---------------------------------] ETA 14s | 00:00:01 so far
#
# Step 42 / 500 [==>---------------------------------] ETA 14s | 00:00:01 so far
#
# Step 43 / 500 [==>---------------------------------] ETA 14s | 00:00:01 so far
#
# Step 44 / 500 [==>---------------------------------] ETA 14s | 00:00:01 so far
#
# Step 45 / 500 [==>---------------------------------] ETA 14s | 00:00:01 so far
#
# Step 46 / 500 [==>---------------------------------] ETA 14s | 00:00:01 so far
#
# Step 47 / 500 [==>---------------------------------] ETA 14s | 00:00:01 so far
#
# Step 48 / 500 [==>---------------------------------] ETA 14s | 00:00:01 so far
#
# Step 49 / 500 [===>--------------------------------] ETA 14s | 00:00:01 so far
#
# Step 50 / 500 [===>--------------------------------] ETA 14s | 00:00:01 so far
#
# Step 51 / 500 [===>--------------------------------] ETA 14s | 00:00:01 so far
#
# Step 52 / 500 [===>--------------------------------] ETA 14s | 00:00:01 so far
#
# Step 53 / 500 [===>--------------------------------] ETA 14s | 00:00:01 so far
#
# Step 54 / 500 [===>--------------------------------] ETA 14s | 00:00:01 so far
#
# Step 55 / 500 [===>--------------------------------] ETA 14s | 00:00:01 so far
#
# Step 56 / 500 [===>--------------------------------] ETA 14s | 00:00:01 so far
#
# Step 57 / 500 [===>--------------------------------] ETA 14s | 00:00:01 so far
#
# Step 58 / 500 [===>--------------------------------] ETA 14s | 00:00:01 so far
#
# Step 59 / 500 [===>--------------------------------] ETA 14s | 00:00:01 so far
#
# Step 60 / 500 [===>--------------------------------] ETA 14s | 00:00:01 so far
#
# Step 61 / 500 [===>--------------------------------] ETA 14s | 00:00:01 so far
#
# Step 62 / 500 [===>--------------------------------] ETA 14s | 00:00:01 so far
#
# Step 63 / 500 [====>-------------------------------] ETA 14s | 00:00:02 so far
#
# Step 64 / 500 [====>-------------------------------] ETA 14s | 00:00:02 so far
#
# Step 65 / 500 [====>-------------------------------] ETA 14s | 00:00:02 so far
#
# Step 66 / 500 [====>-------------------------------] ETA 14s | 00:00:02 so far
#
# Step 67 / 500 [====>-------------------------------] ETA 14s | 00:00:02 so far
#
# Step 68 / 500 [====>-------------------------------] ETA 14s | 00:00:02 so far
#
# Step 69 / 500 [====>-------------------------------] ETA 14s | 00:00:02 so far
#
# Step 70 / 500 [====>-------------------------------] ETA 14s | 00:00:02 so far
#
# Step 71 / 500 [====>-------------------------------] ETA 14s | 00:00:02 so far
#
# Step 72 / 500 [====>-------------------------------] ETA 14s | 00:00:02 so far
#
# Step 73 / 500 [====>-------------------------------] ETA 14s | 00:00:02 so far
#
# Step 74 / 500 [====>-------------------------------] ETA 14s | 00:00:02 so far
#
# Step 75 / 500 [====>-------------------------------] ETA 14s | 00:00:02 so far
#
# Step 76 / 500 [====>-------------------------------] ETA 14s | 00:00:02 so far
#
# Step 77 / 500 [=====>------------------------------] ETA 14s | 00:00:02 so far
#
# Step 78 / 500 [=====>------------------------------] ETA 14s | 00:00:02 so far
#
# Step 79 / 500 [=====>------------------------------] ETA 14s | 00:00:02 so far
#
# Step 80 / 500 [=====>------------------------------] ETA 14s | 00:00:02 so far
#
# Step 81 / 500 [=====>------------------------------] ETA 14s | 00:00:02 so far
#
# Step 82 / 500 [=====>------------------------------] ETA 14s | 00:00:02 so far
#
# Step 83 / 500 [=====>------------------------------] ETA 14s | 00:00:02 so far
#
# Step 84 / 500 [=====>------------------------------] ETA 14s | 00:00:02 so far
#
# Step 85 / 500 [=====>------------------------------] ETA 14s | 00:00:02 so far
#
# Step 86 / 500 [=====>------------------------------] ETA 14s | 00:00:02 so far
#
# Step 87 / 500 [=====>------------------------------] ETA 13s | 00:00:02 so far
#
# Step 88 / 500 [=====>------------------------------] ETA 13s | 00:00:02 so far
#
# Step 89 / 500 [=====>------------------------------] ETA 13s | 00:00:02 so far
#
# Step 90 / 500 [=====>------------------------------] ETA 13s | 00:00:02 so far
#
# Step 91 / 500 [======>-----------------------------] ETA 13s | 00:00:02 so far
#
# Step 92 / 500 [======>-----------------------------] ETA 13s | 00:00:02 so far
#
# Step 93 / 500 [======>-----------------------------] ETA 13s | 00:00:02 so far
#
# Step 94 / 500 [======>-----------------------------] ETA 13s | 00:00:03 so far
#
# Step 95 / 500 [======>-----------------------------] ETA 13s | 00:00:03 so far
#
# Step 96 / 500 [======>-----------------------------] ETA 13s | 00:00:03 so far
#
# Step 97 / 500 [======>-----------------------------] ETA 13s | 00:00:03 so far
#
# Step 98 / 500 [======>-----------------------------] ETA 13s | 00:00:03 so far
#
# Step 99 / 500 [======>-----------------------------] ETA 13s | 00:00:03 so far
#
# Step 100 / 500 [======>----------------------------] ETA 13s | 00:00:03 so far
#
# Step 101 / 500 [======>----------------------------] ETA 13s | 00:00:03 so far
#
# Step 102 / 500 [======>----------------------------] ETA 13s | 00:00:03 so far
#
# Step 103 / 500 [======>----------------------------] ETA 13s | 00:00:03 so far
#
# Step 104 / 500 [======>----------------------------] ETA 13s | 00:00:03 so far
#
# Step 105 / 500 [======>----------------------------] ETA 13s | 00:00:03 so far
#
# Step 106 / 500 [======>----------------------------] ETA 13s | 00:00:03 so far
#
# Step 107 / 500 [======>----------------------------] ETA 13s | 00:00:03 so far
#
# Step 108 / 500 [=======>---------------------------] ETA 13s | 00:00:03 so far
#
# Step 109 / 500 [=======>---------------------------] ETA 13s | 00:00:03 so far
#
# Step 110 / 500 [=======>---------------------------] ETA 13s | 00:00:03 so far
#
# Step 111 / 500 [=======>---------------------------] ETA 12s | 00:00:03 so far
#
# Step 112 / 500 [=======>---------------------------] ETA 12s | 00:00:03 so far
#
# Step 113 / 500 [=======>---------------------------] ETA 12s | 00:00:03 so far
#
# Step 114 / 500 [=======>---------------------------] ETA 12s | 00:00:03 so far
#
# Step 115 / 500 [=======>---------------------------] ETA 12s | 00:00:03 so far
#
# Step 116 / 500 [=======>---------------------------] ETA 12s | 00:00:03 so far
#
# Step 117 / 500 [=======>---------------------------] ETA 12s | 00:00:03 so far
#
# Step 118 / 500 [=======>---------------------------] ETA 12s | 00:00:03 so far
#
# Step 119 / 500 [=======>---------------------------] ETA 12s | 00:00:03 so far
#
# Step 120 / 500 [=======>---------------------------] ETA 12s | 00:00:03 so far
#
# Step 121 / 500 [=======>---------------------------] ETA 12s | 00:00:03 so far
#
# Step 122 / 500 [========>--------------------------] ETA 12s | 00:00:03 so far
#
# Step 123 / 500 [========>--------------------------] ETA 12s | 00:00:03 so far
#
# Step 124 / 500 [========>--------------------------] ETA 12s | 00:00:03 so far
#
# Step 125 / 500 [========>--------------------------] ETA 12s | 00:00:03 so far
#
# Step 126 / 500 [========>--------------------------] ETA 12s | 00:00:03 so far
#
# Step 127 / 500 [========>--------------------------] ETA 12s | 00:00:04 so far
#
# Step 128 / 500 [========>--------------------------] ETA 12s | 00:00:04 so far
#
# Step 129 / 500 [========>--------------------------] ETA 12s | 00:00:04 so far
#
# Step 130 / 500 [========>--------------------------] ETA 12s | 00:00:04 so far
#
# Step 131 / 500 [========>--------------------------] ETA 12s | 00:00:04 so far
#
# Step 132 / 500 [========>--------------------------] ETA 12s | 00:00:04 so far
#
# Step 133 / 500 [========>--------------------------] ETA 12s | 00:00:04 so far
#
# Step 134 / 500 [========>--------------------------] ETA 12s | 00:00:04 so far
#
# Step 135 / 500 [========>--------------------------] ETA 12s | 00:00:04 so far
#
# Step 136 / 500 [=========>-------------------------] ETA 12s | 00:00:04 so far
#
# Step 137 / 500 [=========>-------------------------] ETA 12s | 00:00:04 so far
#
# Step 138 / 500 [=========>-------------------------] ETA 11s | 00:00:04 so far
#
# Step 139 / 500 [=========>-------------------------] ETA 11s | 00:00:04 so far
#
# Step 140 / 500 [=========>-------------------------] ETA 11s | 00:00:04 so far
#
# Step 141 / 500 [=========>-------------------------] ETA 11s | 00:00:04 so far
#
# Step 142 / 500 [=========>-------------------------] ETA 11s | 00:00:04 so far
#
# Step 143 / 500 [=========>-------------------------] ETA 11s | 00:00:04 so far
#
# Step 144 / 500 [=========>-------------------------] ETA 11s | 00:00:04 so far
#
# Step 145 / 500 [=========>-------------------------] ETA 11s | 00:00:04 so far
#
# Step 146 / 500 [=========>-------------------------] ETA 11s | 00:00:04 so far
#
# Step 147 / 500 [=========>-------------------------] ETA 11s | 00:00:04 so far
#
# Step 148 / 500 [=========>-------------------------] ETA 11s | 00:00:04 so far
#
# Step 149 / 500 [=========>-------------------------] ETA 11s | 00:00:04 so far
#
# Step 150 / 500 [=========>-------------------------] ETA 11s | 00:00:04 so far
#
# Step 151 / 500 [==========>------------------------] ETA 11s | 00:00:04 so far
#
# Step 152 / 500 [==========>------------------------] ETA 11s | 00:00:04 so far
#
# Step 153 / 500 [==========>------------------------] ETA 11s | 00:00:04 so far
#
# Step 154 / 500 [==========>------------------------] ETA 11s | 00:00:04 so far
#
# Step 155 / 500 [==========>------------------------] ETA 11s | 00:00:04 so far
#
# Step 156 / 500 [==========>------------------------] ETA 11s | 00:00:04 so far
#
# Step 157 / 500 [==========>------------------------] ETA 11s | 00:00:04 so far
#
# Step 158 / 500 [==========>------------------------] ETA 11s | 00:00:04 so far
#
# Step 159 / 500 [==========>------------------------] ETA 11s | 00:00:05 so far
#
# Step 160 / 500 [==========>------------------------] ETA 11s | 00:00:05 so far
#
# Step 161 / 500 [==========>------------------------] ETA 11s | 00:00:05 so far
#
# Step 162 / 500 [==========>------------------------] ETA 11s | 00:00:05 so far
#
# Step 163 / 500 [==========>------------------------] ETA 11s | 00:00:05 so far
#
# Step 164 / 500 [==========>------------------------] ETA 11s | 00:00:05 so far
#
# Step 165 / 500 [===========>-----------------------] ETA 11s | 00:00:05 so far
#
# Step 166 / 500 [===========>-----------------------] ETA 11s | 00:00:05 so far
#
# Step 167 / 500 [===========>-----------------------] ETA 10s | 00:00:05 so far
#
# Step 168 / 500 [===========>-----------------------] ETA 10s | 00:00:05 so far
#
# Step 169 / 500 [===========>-----------------------] ETA 10s | 00:00:05 so far
#
# Step 170 / 500 [===========>-----------------------] ETA 10s | 00:00:05 so far
#
# Step 171 / 500 [===========>-----------------------] ETA 10s | 00:00:05 so far
#
# Step 172 / 500 [===========>-----------------------] ETA 10s | 00:00:05 so far
#
# Step 173 / 500 [===========>-----------------------] ETA 10s | 00:00:05 so far
#
# Step 174 / 500 [===========>-----------------------] ETA 10s | 00:00:05 so far
#
# Step 175 / 500 [===========>-----------------------] ETA 10s | 00:00:05 so far
#
# Step 176 / 500 [===========>-----------------------] ETA 10s | 00:00:05 so far
#
# Step 177 / 500 [===========>-----------------------] ETA 10s | 00:00:05 so far
#
# Step 178 / 500 [===========>-----------------------] ETA 10s | 00:00:05 so far
#
# Step 179 / 500 [============>----------------------] ETA 10s | 00:00:05 so far
#
# Step 180 / 500 [============>----------------------] ETA 10s | 00:00:05 so far
#
# Step 181 / 500 [============>----------------------] ETA 10s | 00:00:05 so far
#
# Step 182 / 500 [============>----------------------] ETA 10s | 00:00:05 so far
#
# Step 183 / 500 [============>----------------------] ETA 10s | 00:00:05 so far
#
# Step 184 / 500 [============>----------------------] ETA 10s | 00:00:05 so far
#
# Step 185 / 500 [============>----------------------] ETA 10s | 00:00:05 so far
#
# Step 186 / 500 [============>----------------------] ETA 10s | 00:00:05 so far
#
# Step 187 / 500 [============>----------------------] ETA 10s | 00:00:05 so far
#
# Step 188 / 500 [============>----------------------] ETA 10s | 00:00:05 so far
#
# Step 189 / 500 [============>----------------------] ETA 10s | 00:00:05 so far
#
# Step 190 / 500 [============>----------------------] ETA 10s | 00:00:05 so far
#
# Step 191 / 500 [============>----------------------] ETA 10s | 00:00:05 so far
#
# Step 192 / 500 [============>----------------------] ETA 10s | 00:00:06 so far
#
# Step 193 / 500 [=============>---------------------] ETA 10s | 00:00:06 so far
#
# Step 194 / 500 [=============>---------------------] ETA 10s | 00:00:06 so far
#
# Step 195 / 500 [=============>---------------------] ETA 10s | 00:00:06 so far
#
# Step 196 / 500 [=============>---------------------] ETA 10s | 00:00:06 so far
#
# Step 197 / 500 [=============>---------------------] ETA  9s | 00:00:06 so far
#
# Step 198 / 500 [=============>---------------------] ETA  9s | 00:00:06 so far
#
# Step 199 / 500 [=============>---------------------] ETA  9s | 00:00:06 so far
#
# Step 200 / 500 [=============>---------------------] ETA  9s | 00:00:06 so far
#
# Step 201 / 500 [=============>---------------------] ETA  9s | 00:00:06 so far
#
# Step 202 / 500 [=============>---------------------] ETA  9s | 00:00:06 so far
#
# Step 203 / 500 [=============>---------------------] ETA  9s | 00:00:06 so far
#
# Step 204 / 500 [=============>---------------------] ETA  9s | 00:00:06 so far
#
# Step 205 / 500 [=============>---------------------] ETA  9s | 00:00:06 so far
#
# Step 206 / 500 [=============>---------------------] ETA  9s | 00:00:06 so far
#
# Step 207 / 500 [=============>---------------------] ETA  9s | 00:00:06 so far
#
# Step 208 / 500 [==============>--------------------] ETA  9s | 00:00:06 so far
#
# Step 209 / 500 [==============>--------------------] ETA  9s | 00:00:06 so far
#
# Step 210 / 500 [==============>--------------------] ETA  9s | 00:00:06 so far
#
# Step 211 / 500 [==============>--------------------] ETA  9s | 00:00:06 so far
#
# Step 212 / 500 [==============>--------------------] ETA  9s | 00:00:06 so far
#
# Step 213 / 500 [==============>--------------------] ETA  9s | 00:00:06 so far
#
# Step 214 / 500 [==============>--------------------] ETA  9s | 00:00:06 so far
#
# Step 215 / 500 [==============>--------------------] ETA  9s | 00:00:06 so far
#
# Step 216 / 500 [==============>--------------------] ETA  9s | 00:00:06 so far
#
# Step 217 / 500 [==============>--------------------] ETA  9s | 00:00:06 so far
#
# Step 218 / 500 [==============>--------------------] ETA  9s | 00:00:06 so far
#
# Step 219 / 500 [==============>--------------------] ETA  9s | 00:00:06 so far
#
# Step 220 / 500 [==============>--------------------] ETA  9s | 00:00:06 so far
#
# Step 221 / 500 [==============>--------------------] ETA  9s | 00:00:06 so far
#
# Step 222 / 500 [===============>-------------------] ETA  9s | 00:00:06 so far
#
# Step 223 / 500 [===============>-------------------] ETA  9s | 00:00:06 so far
#
# Step 224 / 500 [===============>-------------------] ETA  9s | 00:00:07 so far
#
# Step 225 / 500 [===============>-------------------] ETA  9s | 00:00:07 so far
#
# Step 226 / 500 [===============>-------------------] ETA  9s | 00:00:07 so far
#
# Step 227 / 500 [===============>-------------------] ETA  9s | 00:00:07 so far
#
# Step 228 / 500 [===============>-------------------] ETA  9s | 00:00:07 so far
#
# Step 229 / 500 [===============>-------------------] ETA  9s | 00:00:07 so far
#
# Step 230 / 500 [===============>-------------------] ETA  8s | 00:00:07 so far
#
# Step 231 / 500 [===============>-------------------] ETA  8s | 00:00:07 so far
#
# Step 232 / 500 [===============>-------------------] ETA  8s | 00:00:07 so far
#
# Step 233 / 500 [===============>-------------------] ETA  8s | 00:00:07 so far
#
# Step 234 / 500 [===============>-------------------] ETA  8s | 00:00:07 so far
#
# Step 235 / 500 [===============>-------------------] ETA  8s | 00:00:07 so far
#
# Step 236 / 500 [================>------------------] ETA  8s | 00:00:07 so far
#
# Step 237 / 500 [================>------------------] ETA  8s | 00:00:07 so far
#
# Step 238 / 500 [================>------------------] ETA  8s | 00:00:07 so far
#
# Step 239 / 500 [================>------------------] ETA  8s | 00:00:07 so far
#
# Step 240 / 500 [================>------------------] ETA  8s | 00:00:07 so far
#
# Step 241 / 500 [================>------------------] ETA  8s | 00:00:07 so far
#
# Step 242 / 500 [================>------------------] ETA  8s | 00:00:07 so far
#
# Step 243 / 500 [================>------------------] ETA  8s | 00:00:07 so far
#
# Step 244 / 500 [================>------------------] ETA  8s | 00:00:07 so far
#
# Step 245 / 500 [================>------------------] ETA  8s | 00:00:07 so far
#
# Step 246 / 500 [================>------------------] ETA  8s | 00:00:07 so far
#
# Step 247 / 500 [================>------------------] ETA  8s | 00:00:07 so far
#
# Step 248 / 500 [================>------------------] ETA  8s | 00:00:07 so far
#
# Step 249 / 500 [================>------------------] ETA  8s | 00:00:07 so far
#
# Step 250 / 500 [=================>-----------------] ETA  8s | 00:00:07 so far
#
# Step 251 / 500 [=================>-----------------] ETA  8s | 00:00:07 so far
#
# Step 252 / 500 [=================>-----------------] ETA  8s | 00:00:07 so far
#
# Step 253 / 500 [=================>-----------------] ETA  8s | 00:00:07 so far
#
# Step 254 / 500 [=================>-----------------] ETA  8s | 00:00:07 so far
#
# Step 255 / 500 [=================>-----------------] ETA  8s | 00:00:07 so far
#
# Step 256 / 500 [=================>-----------------] ETA  8s | 00:00:07 so far
#
# Step 257 / 500 [=================>-----------------] ETA  8s | 00:00:08 so far
#
# Step 258 / 500 [=================>-----------------] ETA  8s | 00:00:08 so far
#
# Step 259 / 500 [=================>-----------------] ETA  8s | 00:00:08 so far
#
# Step 260 / 500 [=================>-----------------] ETA  8s | 00:00:08 so far
#
# Step 261 / 500 [=================>-----------------] ETA  7s | 00:00:08 so far
#
# Step 262 / 500 [=================>-----------------] ETA  7s | 00:00:08 so far
#
# Step 263 / 500 [=================>-----------------] ETA  7s | 00:00:08 so far
#
# Step 264 / 500 [=================>-----------------] ETA  7s | 00:00:08 so far
#
# Step 265 / 500 [==================>----------------] ETA  7s | 00:00:08 so far
#
# Step 266 / 500 [==================>----------------] ETA  7s | 00:00:08 so far
#
# Step 267 / 500 [==================>----------------] ETA  7s | 00:00:08 so far
#
# Step 268 / 500 [==================>----------------] ETA  7s | 00:00:08 so far
#
# Step 269 / 500 [==================>----------------] ETA  7s | 00:00:08 so far
#
# Step 270 / 500 [==================>----------------] ETA  7s | 00:00:08 so far
#
# Step 271 / 500 [==================>----------------] ETA  7s | 00:00:08 so far
#
# Step 272 / 500 [==================>----------------] ETA  7s | 00:00:08 so far
#
# Step 273 / 500 [==================>----------------] ETA  7s | 00:00:08 so far
#
# Step 274 / 500 [==================>----------------] ETA  7s | 00:00:08 so far
#
# Step 275 / 500 [==================>----------------] ETA  7s | 00:00:08 so far
#
# Step 276 / 500 [==================>----------------] ETA  7s | 00:00:08 so far
#
# Step 277 / 500 [==================>----------------] ETA  7s | 00:00:08 so far
#
# Step 278 / 500 [==================>----------------] ETA  7s | 00:00:08 so far
#
# Step 279 / 500 [===================>---------------] ETA  7s | 00:00:08 so far
#
# Step 280 / 500 [===================>---------------] ETA  7s | 00:00:08 so far
#
# Step 281 / 500 [===================>---------------] ETA  7s | 00:00:08 so far
#
# Step 282 / 500 [===================>---------------] ETA  7s | 00:00:08 so far
#
# Step 283 / 500 [===================>---------------] ETA  7s | 00:00:08 so far
#
# Step 284 / 500 [===================>---------------] ETA  7s | 00:00:08 so far
#
# Step 285 / 500 [===================>---------------] ETA  7s | 00:00:08 so far
#
# Step 286 / 500 [===================>---------------] ETA  7s | 00:00:08 so far
#
# Step 287 / 500 [===================>---------------] ETA  7s | 00:00:08 so far
#
# Step 288 / 500 [===================>---------------] ETA  7s | 00:00:08 so far
#
# Step 289 / 500 [===================>---------------] ETA  7s | 00:00:08 so far
#
# Step 290 / 500 [===================>---------------] ETA  7s | 00:00:09 so far
#
# Step 291 / 500 [===================>---------------] ETA  7s | 00:00:09 so far
#
# Step 292 / 500 [===================>---------------] ETA  6s | 00:00:09 so far
#
# Step 293 / 500 [====================>--------------] ETA  6s | 00:00:09 so far
#
# Step 294 / 500 [====================>--------------] ETA  6s | 00:00:09 so far
#
# Step 295 / 500 [====================>--------------] ETA  6s | 00:00:09 so far
#
# Step 296 / 500 [====================>--------------] ETA  6s | 00:00:09 so far
#
# Step 297 / 500 [====================>--------------] ETA  6s | 00:00:09 so far
#
# Step 298 / 500 [====================>--------------] ETA  6s | 00:00:09 so far
#
# Step 299 / 500 [====================>--------------] ETA  6s | 00:00:09 so far
#
# Step 300 / 500 [====================>--------------] ETA  6s | 00:00:09 so far
#
# Step 301 / 500 [====================>--------------] ETA  6s | 00:00:09 so far
#
# Step 302 / 500 [====================>--------------] ETA  6s | 00:00:09 so far
#
# Step 303 / 500 [====================>--------------] ETA  6s | 00:00:09 so far
#
# Step 304 / 500 [====================>--------------] ETA  6s | 00:00:09 so far
#
# Step 305 / 500 [====================>--------------] ETA  6s | 00:00:09 so far
#
# Step 306 / 500 [====================>--------------] ETA  6s | 00:00:09 so far
#
# Step 307 / 500 [====================>--------------] ETA  6s | 00:00:09 so far
#
# Step 308 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 309 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 310 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 311 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 312 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 313 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 314 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 315 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 316 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 317 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 318 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 319 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 320 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 321 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 322 / 500 [======================>------------] ETA  6s | 00:00:09 so far
#
# Step 323 / 500 [======================>------------] ETA  5s | 00:00:10 so far
#
# Step 324 / 500 [======================>------------] ETA  5s | 00:00:10 so far
#
# Step 325 / 500 [======================>------------] ETA  5s | 00:00:10 so far
#
# Step 326 / 500 [======================>------------] ETA  5s | 00:00:10 so far
#
# Step 327 / 500 [======================>------------] ETA  5s | 00:00:10 so far
#
# Step 328 / 500 [======================>------------] ETA  5s | 00:00:10 so far
#
# Step 329 / 500 [======================>------------] ETA  5s | 00:00:10 so far
#
# Step 330 / 500 [======================>------------] ETA  5s | 00:00:10 so far
#
# Step 331 / 500 [======================>------------] ETA  5s | 00:00:10 so far
#
# Step 332 / 500 [======================>------------] ETA  5s | 00:00:10 so far
#
# Step 333 / 500 [======================>------------] ETA  5s | 00:00:10 so far
#
# Step 334 / 500 [======================>------------] ETA  5s | 00:00:10 so far
#
# Step 335 / 500 [======================>------------] ETA  5s | 00:00:10 so far
#
# Step 336 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 337 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 338 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 339 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 340 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 341 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 342 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 343 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 344 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 345 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 346 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 347 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 348 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 349 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 350 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 351 / 500 [========================>----------] ETA  5s | 00:00:10 so far
#
# Step 352 / 500 [========================>----------] ETA  5s | 00:00:10 so far
#
# Step 353 / 500 [========================>----------] ETA  5s | 00:00:10 so far
#
# Step 354 / 500 [========================>----------] ETA  5s | 00:00:10 so far
#
# Step 355 / 500 [========================>----------] ETA  5s | 00:00:11 so far
#
# Step 356 / 500 [========================>----------] ETA  4s | 00:00:11 so far
#
# Step 357 / 500 [========================>----------] ETA  4s | 00:00:11 so far
#
# Step 358 / 500 [========================>----------] ETA  4s | 00:00:11 so far
#
# Step 359 / 500 [========================>----------] ETA  4s | 00:00:11 so far
#
# Step 360 / 500 [========================>----------] ETA  4s | 00:00:11 so far
#
# Step 361 / 500 [========================>----------] ETA  4s | 00:00:11 so far
#
# Step 362 / 500 [========================>----------] ETA  4s | 00:00:11 so far
#
# Step 363 / 500 [========================>----------] ETA  4s | 00:00:11 so far
#
# Step 364 / 500 [========================>----------] ETA  4s | 00:00:11 so far
#
# Step 365 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 366 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 367 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 368 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 369 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 370 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 371 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 372 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 373 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 374 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 375 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 376 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 377 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 378 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 379 / 500 [==========================>--------] ETA  4s | 00:00:11 so far
#
# Step 380 / 500 [==========================>--------] ETA  4s | 00:00:11 so far
#
# Step 381 / 500 [==========================>--------] ETA  4s | 00:00:11 so far
#
# Step 382 / 500 [==========================>--------] ETA  4s | 00:00:11 so far
#
# Step 383 / 500 [==========================>--------] ETA  4s | 00:00:11 so far
#
# Step 384 / 500 [==========================>--------] ETA  4s | 00:00:12 so far
#
# Step 385 / 500 [==========================>--------] ETA  4s | 00:00:12 so far
#
# Step 386 / 500 [==========================>--------] ETA  4s | 00:00:12 so far
#
# Step 387 / 500 [==========================>--------] ETA  4s | 00:00:12 so far
#
# Step 388 / 500 [==========================>--------] ETA  4s | 00:00:12 so far
#
# Step 389 / 500 [==========================>--------] ETA  3s | 00:00:12 so far
#
# Step 390 / 500 [==========================>--------] ETA  3s | 00:00:12 so far
#
# Step 391 / 500 [==========================>--------] ETA  3s | 00:00:12 so far
#
# Step 392 / 500 [==========================>--------] ETA  3s | 00:00:12 so far
#
# Step 393 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 394 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 395 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 396 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 397 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 398 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 399 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 400 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 401 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 402 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 403 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 404 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 405 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 406 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 407 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 408 / 500 [============================>------] ETA  3s | 00:00:12 so far
#
# Step 409 / 500 [============================>------] ETA  3s | 00:00:12 so far
#
# Step 410 / 500 [============================>------] ETA  3s | 00:00:12 so far
#
# Step 411 / 500 [============================>------] ETA  3s | 00:00:12 so far
#
# Step 412 / 500 [============================>------] ETA  3s | 00:00:12 so far
#
# Step 413 / 500 [============================>------] ETA  3s | 00:00:12 so far
#
# Step 414 / 500 [============================>------] ETA  3s | 00:00:12 so far
#
# Step 415 / 500 [============================>------] ETA  3s | 00:00:13 so far
#
# Step 416 / 500 [============================>------] ETA  3s | 00:00:13 so far
#
# Step 417 / 500 [============================>------] ETA  3s | 00:00:13 so far
#
# Step 418 / 500 [============================>------] ETA  3s | 00:00:13 so far
#
# Step 419 / 500 [============================>------] ETA  3s | 00:00:13 so far
#
# Step 420 / 500 [============================>------] ETA  3s | 00:00:13 so far
#
# Step 421 / 500 [============================>------] ETA  2s | 00:00:13 so far
#
# Step 422 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 423 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 424 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 425 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 426 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 427 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 428 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 429 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 430 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 431 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 432 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 433 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 434 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 435 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 436 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 437 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 438 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 439 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 440 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 441 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 442 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 443 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 444 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 445 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 446 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 447 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 448 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 449 / 500 [==============================>----] ETA  2s | 00:00:14 so far
#
# Step 450 / 500 [===============================>---] ETA  2s | 00:00:14 so far
#
# Step 451 / 500 [===============================>---] ETA  2s | 00:00:14 so far
#
# Step 452 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 453 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 454 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 455 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 456 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 457 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 458 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 459 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 460 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 461 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 462 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 463 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 464 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 465 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 466 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 467 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 468 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 469 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 470 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 471 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 472 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 473 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 474 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 475 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 476 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 477 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 478 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 479 / 500 [=================================>-] ETA  1s | 00:00:14 so far
#
# Step 480 / 500 [=================================>-] ETA  1s | 00:00:14 so far
#
# Step 481 / 500 [=================================>-] ETA  1s | 00:00:14 so far
#
# Step 482 / 500 [=================================>-] ETA  1s | 00:00:15 so far
#
# Step 483 / 500 [=================================>-] ETA  1s | 00:00:15 so far
#
# Step 484 / 500 [=================================>-] ETA  0s | 00:00:15 so far
#
# Step 485 / 500 [=================================>-] ETA  0s | 00:00:15 so far
#
# Step 486 / 500 [=================================>-] ETA  0s | 00:00:15 so far
#
# Step 487 / 500 [=================================>-] ETA  0s | 00:00:15 so far
#
# Step 488 / 500 [=================================>-] ETA  0s | 00:00:15 so far
#
# Step 489 / 500 [=================================>-] ETA  0s | 00:00:15 so far
#
# Step 490 / 500 [=================================>-] ETA  0s | 00:00:15 so far
#
# Step 491 / 500 [=================================>-] ETA  0s | 00:00:15 so far
#
# Step 492 / 500 [=================================>-] ETA  0s | 00:00:15 so far
#
# Step 493 / 500 [==================================>] ETA  0s | 00:00:15 so far
#
# Step 494 / 500 [==================================>] ETA  0s | 00:00:15 so far
#
# Step 495 / 500 [==================================>] ETA  0s | 00:00:15 so far
#
# Step 496 / 500 [==================================>] ETA  0s | 00:00:15 so far
#
# Step 497 / 500 [==================================>] ETA  0s | 00:00:15 so far
#
# Step 498 / 500 [==================================>] ETA  0s | 00:00:15 so far
#
# Step 499 / 500 [==================================>] ETA  0s | 00:00:15 so far
#
# Step 500 / 500 [===================================] ETA  0s | 00:00:15 so far
#
#
# Finished 500 steps in 16 secs

# %%
processed_chains <- mcstate::pmcmc_thin(pmcmc_run, burnin = n_burnin, thin = 2)
parameter_mean_hpd <- apply(processed_chains$pars, 2, mean)
parameter_mean_hpd
# Out:
#      beta     gamma
# 0.7482551 0.1770996

# %% [markdown]
# **Tuning the MCMC**

# %%
proposal_matrix <- cov(pmcmc_run$pars)
mcmc_pars <- mcstate::pmcmc_parameters$new(
  list(beta = beta, gamma = gamma),
  proposal_matrix)
proposal_matrix
# Out:
#       beta        gamma
# beta  0.003988641 0.002485005
# gamma 0.002485005 0.001824264

# %%
control <- mcstate::pmcmc_control(
    n_steps,
    save_state = TRUE,
    save_trajectories = TRUE,
    progress = TRUE,
    n_chains = 4)
pmcmc_tuned_run <- mcstate::pmcmc(mcmc_pars, filter, control = control)
# Out:
# Running chain 1 / 4
#
#
# Step 20 / 500 [>-----------------------------------] ETA  5s | 00:00:00 so far
#
# Step 21 / 500 [=>----------------------------------] ETA  6s | 00:00:00 so far
#
# Step 22 / 500 [=>----------------------------------] ETA  6s | 00:00:00 so far
#
# Step 23 / 500 [=>----------------------------------] ETA  6s | 00:00:00 so far
#
# Step 24 / 500 [=>----------------------------------] ETA  7s | 00:00:00 so far
#
# Step 25 / 500 [=>----------------------------------] ETA  7s | 00:00:00 so far
#
# Step 26 / 500 [=>----------------------------------] ETA  7s | 00:00:00 so far
#
# Step 27 / 500 [=>----------------------------------] ETA  8s | 00:00:00 so far
#
# Step 28 / 500 [=>----------------------------------] ETA  8s | 00:00:00 so far
#
# Step 29 / 500 [=>----------------------------------] ETA  8s | 00:00:00 so far
#
# Step 30 / 500 [=>----------------------------------] ETA  8s | 00:00:00 so far
#
# Step 31 / 500 [=>----------------------------------] ETA  8s | 00:00:00 so far
#
# Step 32 / 500 [=>----------------------------------] ETA  9s | 00:00:00 so far
#
# Step 33 / 500 [=>----------------------------------] ETA  9s | 00:00:00 so far
#
# Step 34 / 500 [=>----------------------------------] ETA  9s | 00:00:00 so far
#
# Step 35 / 500 [==>---------------------------------] ETA  9s | 00:00:00 so far
#
# Step 36 / 500 [==>---------------------------------] ETA  9s | 00:00:00 so far
#
# Step 37 / 500 [==>---------------------------------] ETA  9s | 00:00:00 so far
#
# Step 38 / 500 [==>---------------------------------] ETA  9s | 00:00:00 so far
#
# Step 39 / 500 [==>---------------------------------] ETA 10s | 00:00:00 so far
#
# Step 40 / 500 [==>---------------------------------] ETA 10s | 00:00:00 so far
#
# Step 41 / 500 [==>---------------------------------] ETA 10s | 00:00:00 so far
#
# Step 42 / 500 [==>---------------------------------] ETA 10s | 00:00:00 so far
#
# Step 43 / 500 [==>---------------------------------] ETA 10s | 00:00:00 so far
#
# Step 44 / 500 [==>---------------------------------] ETA 10s | 00:00:00 so far
#
# Step 45 / 500 [==>---------------------------------] ETA 10s | 00:00:00 so far
#
# Step 46 / 500 [==>---------------------------------] ETA 10s | 00:00:01 so far
#
# Step 47 / 500 [==>---------------------------------] ETA 10s | 00:00:01 so far
#
# Step 48 / 500 [==>---------------------------------] ETA 10s | 00:00:01 so far
#
# Step 49 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 50 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 51 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 52 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 53 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 54 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 55 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 56 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 57 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 58 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 59 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 60 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 61 / 500 [===>--------------------------------] ETA 11s | 00:00:01 so far
#
# Step 62 / 500 [===>--------------------------------] ETA 11s | 00:00:01 so far
#
# Step 63 / 500 [====>-------------------------------] ETA 11s | 00:00:01 so far
#
# Step 64 / 500 [====>-------------------------------] ETA 11s | 00:00:01 so far
#
# Step 65 / 500 [====>-------------------------------] ETA 11s | 00:00:01 so far
#
# Step 66 / 500 [====>-------------------------------] ETA 11s | 00:00:01 so far
#
# Step 67 / 500 [====>-------------------------------] ETA 11s | 00:00:01 so far
#
# Step 68 / 500 [====>-------------------------------] ETA 11s | 00:00:01 so far
#
# Step 69 / 500 [====>-------------------------------] ETA 11s | 00:00:01 so far
#
# Step 70 / 500 [====>-------------------------------] ETA 11s | 00:00:01 so far
#
# Step 71 / 500 [====>-------------------------------] ETA 11s | 00:00:01 so far
#
# Step 72 / 500 [====>-------------------------------] ETA 11s | 00:00:01 so far
#
# Step 73 / 500 [====>-------------------------------] ETA 11s | 00:00:01 so far
#
# Step 74 / 500 [====>-------------------------------] ETA 11s | 00:00:01 so far
#
# Step 75 / 500 [====>-------------------------------] ETA 11s | 00:00:01 so far
#
# Step 76 / 500 [====>-------------------------------] ETA 11s | 00:00:01 so far
#
# Step 77 / 500 [=====>------------------------------] ETA 11s | 00:00:01 so far
#
# Step 78 / 500 [=====>------------------------------] ETA 11s | 00:00:01 so far
#
# Step 79 / 500 [=====>------------------------------] ETA 11s | 00:00:02 so far
#
# Step 80 / 500 [=====>------------------------------] ETA 11s | 00:00:02 so far
#
# Step 81 / 500 [=====>------------------------------] ETA 11s | 00:00:02 so far
#
# Step 82 / 500 [=====>------------------------------] ETA 11s | 00:00:02 so far
#
# Step 83 / 500 [=====>------------------------------] ETA 11s | 00:00:02 so far
#
# Step 84 / 500 [=====>------------------------------] ETA 11s | 00:00:02 so far
#
# Step 85 / 500 [=====>------------------------------] ETA 11s | 00:00:02 so far
#
# Step 86 / 500 [=====>------------------------------] ETA 11s | 00:00:02 so far
#
# Step 87 / 500 [=====>------------------------------] ETA 11s | 00:00:02 so far
#
# Step 88 / 500 [=====>------------------------------] ETA 11s | 00:00:02 so far
#
# Step 89 / 500 [=====>------------------------------] ETA 11s | 00:00:02 so far
#
# Step 90 / 500 [=====>------------------------------] ETA 11s | 00:00:02 so far
#
# Step 91 / 500 [======>-----------------------------] ETA 11s | 00:00:02 so far
#
# Step 92 / 500 [======>-----------------------------] ETA 11s | 00:00:02 so far
#
# Step 93 / 500 [======>-----------------------------] ETA 11s | 00:00:02 so far
#
# Step 94 / 500 [======>-----------------------------] ETA 11s | 00:00:02 so far
#
# Step 95 / 500 [======>-----------------------------] ETA 11s | 00:00:02 so far
#
# Step 96 / 500 [======>-----------------------------] ETA 11s | 00:00:02 so far
#
# Step 97 / 500 [======>-----------------------------] ETA 11s | 00:00:02 so far
#
# Step 98 / 500 [======>-----------------------------] ETA 11s | 00:00:02 so far
#
# Step 99 / 500 [======>-----------------------------] ETA 11s | 00:00:02 so far
#
# Step 100 / 500 [======>----------------------------] ETA 11s | 00:00:02 so far
#
# Step 101 / 500 [======>----------------------------] ETA 11s | 00:00:02 so far
#
# Step 102 / 500 [======>----------------------------] ETA 11s | 00:00:02 so far
#
# Step 103 / 500 [======>----------------------------] ETA 11s | 00:00:02 so far
#
# Step 104 / 500 [======>----------------------------] ETA 11s | 00:00:02 so far
#
# Step 105 / 500 [======>----------------------------] ETA 11s | 00:00:02 so far
#
# Step 106 / 500 [======>----------------------------] ETA 11s | 00:00:02 so far
#
# Step 107 / 500 [======>----------------------------] ETA 11s | 00:00:02 so far
#
# Step 108 / 500 [=======>---------------------------] ETA 11s | 00:00:02 so far
#
# Step 109 / 500 [=======>---------------------------] ETA 11s | 00:00:02 so far
#
# Step 110 / 500 [=======>---------------------------] ETA 11s | 00:00:02 so far
#
# Step 111 / 500 [=======>---------------------------] ETA 11s | 00:00:02 so far
#
# Step 112 / 500 [=======>---------------------------] ETA 11s | 00:00:03 so far
#
# Step 113 / 500 [=======>---------------------------] ETA 11s | 00:00:03 so far
#
# Step 114 / 500 [=======>---------------------------] ETA 11s | 00:00:03 so far
#
# Step 115 / 500 [=======>---------------------------] ETA 11s | 00:00:03 so far
#
# Step 116 / 500 [=======>---------------------------] ETA 11s | 00:00:03 so far
#
# Step 117 / 500 [=======>---------------------------] ETA 10s | 00:00:03 so far
#
# Step 118 / 500 [=======>---------------------------] ETA 10s | 00:00:03 so far
#
# Step 119 / 500 [=======>---------------------------] ETA 10s | 00:00:03 so far
#
# Step 120 / 500 [=======>---------------------------] ETA 10s | 00:00:03 so far
#
# Step 121 / 500 [=======>---------------------------] ETA 10s | 00:00:03 so far
#
# Step 122 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 123 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 124 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 125 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 126 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 127 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 128 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 129 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 130 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 131 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 132 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 133 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 134 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 135 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 136 / 500 [=========>-------------------------] ETA 10s | 00:00:03 so far
#
# Step 137 / 500 [=========>-------------------------] ETA 10s | 00:00:03 so far
#
# Step 138 / 500 [=========>-------------------------] ETA 10s | 00:00:03 so far
#
# Step 139 / 500 [=========>-------------------------] ETA 10s | 00:00:03 so far
#
# Step 140 / 500 [=========>-------------------------] ETA 10s | 00:00:03 so far
#
# Step 141 / 500 [=========>-------------------------] ETA 10s | 00:00:03 so far
#
# Step 142 / 500 [=========>-------------------------] ETA 10s | 00:00:03 so far
#
# Step 143 / 500 [=========>-------------------------] ETA 10s | 00:00:03 so far
#
# Step 144 / 500 [=========>-------------------------] ETA 10s | 00:00:04 so far
#
# Step 145 / 500 [=========>-------------------------] ETA 10s | 00:00:04 so far
#
# Step 146 / 500 [=========>-------------------------] ETA 10s | 00:00:04 so far
#
# Step 147 / 500 [=========>-------------------------] ETA 10s | 00:00:04 so far
#
# Step 148 / 500 [=========>-------------------------] ETA 10s | 00:00:04 so far
#
# Step 149 / 500 [=========>-------------------------] ETA 10s | 00:00:04 so far
#
# Step 150 / 500 [=========>-------------------------] ETA 10s | 00:00:04 so far
#
# Step 151 / 500 [==========>------------------------] ETA 10s | 00:00:04 so far
#
# Step 152 / 500 [==========>------------------------] ETA 10s | 00:00:04 so far
#
# Step 153 / 500 [==========>------------------------] ETA 10s | 00:00:04 so far
#
# Step 154 / 500 [==========>------------------------] ETA 10s | 00:00:04 so far
#
# Step 155 / 500 [==========>------------------------] ETA 10s | 00:00:04 so far
#
# Step 156 / 500 [==========>------------------------] ETA 10s | 00:00:04 so far
#
# Step 157 / 500 [==========>------------------------] ETA 10s | 00:00:04 so far
#
# Step 158 / 500 [==========>------------------------] ETA 10s | 00:00:04 so far
#
# Step 159 / 500 [==========>------------------------] ETA 10s | 00:00:04 so far
#
# Step 160 / 500 [==========>------------------------] ETA 10s | 00:00:04 so far
#
# Step 161 / 500 [==========>------------------------] ETA 10s | 00:00:04 so far
#
# Step 162 / 500 [==========>------------------------] ETA 10s | 00:00:04 so far
#
# Step 163 / 500 [==========>------------------------] ETA 10s | 00:00:04 so far
#
# Step 164 / 500 [==========>------------------------] ETA 10s | 00:00:04 so far
#
# Step 165 / 500 [===========>-----------------------] ETA  9s | 00:00:04 so far
#
# Step 166 / 500 [===========>-----------------------] ETA  9s | 00:00:04 so far
#
# Step 167 / 500 [===========>-----------------------] ETA  9s | 00:00:04 so far
#
# Step 168 / 500 [===========>-----------------------] ETA  9s | 00:00:04 so far
#
# Step 169 / 500 [===========>-----------------------] ETA  9s | 00:00:04 so far
#
# Step 170 / 500 [===========>-----------------------] ETA  9s | 00:00:04 so far
#
# Step 171 / 500 [===========>-----------------------] ETA  9s | 00:00:04 so far
#
# Step 172 / 500 [===========>-----------------------] ETA  9s | 00:00:04 so far
#
# Step 173 / 500 [===========>-----------------------] ETA  9s | 00:00:04 so far
#
# Step 174 / 500 [===========>-----------------------] ETA  9s | 00:00:04 so far
#
# Step 175 / 500 [===========>-----------------------] ETA  9s | 00:00:04 so far
#
# Step 176 / 500 [===========>-----------------------] ETA  9s | 00:00:04 so far
#
# Step 177 / 500 [===========>-----------------------] ETA  9s | 00:00:05 so far
#
# Step 178 / 500 [===========>-----------------------] ETA  9s | 00:00:05 so far
#
# Step 179 / 500 [============>----------------------] ETA  9s | 00:00:05 so far
#
# Step 180 / 500 [============>----------------------] ETA  9s | 00:00:05 so far
#
# Step 181 / 500 [============>----------------------] ETA  9s | 00:00:05 so far
#
# Step 182 / 500 [============>----------------------] ETA  9s | 00:00:05 so far
#
# Step 183 / 500 [============>----------------------] ETA  9s | 00:00:05 so far
#
# Step 184 / 500 [============>----------------------] ETA  9s | 00:00:05 so far
#
# Step 185 / 500 [============>----------------------] ETA  9s | 00:00:05 so far
#
# Step 186 / 500 [============>----------------------] ETA  9s | 00:00:05 so far
#
# Step 187 / 500 [============>----------------------] ETA  9s | 00:00:05 so far
#
# Step 188 / 500 [============>----------------------] ETA  9s | 00:00:05 so far
#
# Step 189 / 500 [============>----------------------] ETA  9s | 00:00:05 so far
#
# Step 190 / 500 [============>----------------------] ETA  9s | 00:00:05 so far
#
# Step 191 / 500 [============>----------------------] ETA  9s | 00:00:05 so far
#
# Step 192 / 500 [============>----------------------] ETA  9s | 00:00:05 so far
#
# Step 193 / 500 [=============>---------------------] ETA  9s | 00:00:05 so far
#
# Step 194 / 500 [=============>---------------------] ETA  9s | 00:00:05 so far
#
# Step 195 / 500 [=============>---------------------] ETA  9s | 00:00:05 so far
#
# Step 196 / 500 [=============>---------------------] ETA  9s | 00:00:05 so far
#
# Step 197 / 500 [=============>---------------------] ETA  9s | 00:00:05 so far
#
# Step 198 / 500 [=============>---------------------] ETA  9s | 00:00:05 so far
#
# Step 199 / 500 [=============>---------------------] ETA  9s | 00:00:05 so far
#
# Step 200 / 500 [=============>---------------------] ETA  9s | 00:00:05 so far
#
# Step 201 / 500 [=============>---------------------] ETA  9s | 00:00:05 so far
#
# Step 202 / 500 [=============>---------------------] ETA  9s | 00:00:05 so far
#
# Step 203 / 500 [=============>---------------------] ETA  9s | 00:00:05 so far
#
# Step 204 / 500 [=============>---------------------] ETA  9s | 00:00:05 so far
#
# Step 205 / 500 [=============>---------------------] ETA  8s | 00:00:05 so far
#
# Step 206 / 500 [=============>---------------------] ETA  8s | 00:00:05 so far
#
# Step 207 / 500 [=============>---------------------] ETA  8s | 00:00:05 so far
#
# Step 208 / 500 [==============>--------------------] ETA  8s | 00:00:05 so far
#
# Step 209 / 500 [==============>--------------------] ETA  8s | 00:00:06 so far
#
# Step 210 / 500 [==============>--------------------] ETA  8s | 00:00:06 so far
#
# Step 211 / 500 [==============>--------------------] ETA  8s | 00:00:06 so far
#
# Step 212 / 500 [==============>--------------------] ETA  8s | 00:00:06 so far
#
# Step 213 / 500 [==============>--------------------] ETA  8s | 00:00:06 so far
#
# Step 214 / 500 [==============>--------------------] ETA  8s | 00:00:06 so far
#
# Step 215 / 500 [==============>--------------------] ETA  8s | 00:00:06 so far
#
# Step 216 / 500 [==============>--------------------] ETA  8s | 00:00:06 so far
#
# Step 217 / 500 [==============>--------------------] ETA  8s | 00:00:06 so far
#
# Step 218 / 500 [==============>--------------------] ETA  8s | 00:00:06 so far
#
# Step 219 / 500 [==============>--------------------] ETA  8s | 00:00:06 so far
#
# Step 220 / 500 [==============>--------------------] ETA  8s | 00:00:06 so far
#
# Step 221 / 500 [==============>--------------------] ETA  8s | 00:00:06 so far
#
# Step 222 / 500 [===============>-------------------] ETA  8s | 00:00:06 so far
#
# Step 223 / 500 [===============>-------------------] ETA  8s | 00:00:06 so far
#
# Step 224 / 500 [===============>-------------------] ETA  8s | 00:00:06 so far
#
# Step 225 / 500 [===============>-------------------] ETA  8s | 00:00:06 so far
#
# Step 226 / 500 [===============>-------------------] ETA  8s | 00:00:06 so far
#
# Step 227 / 500 [===============>-------------------] ETA  8s | 00:00:06 so far
#
# Step 228 / 500 [===============>-------------------] ETA  8s | 00:00:06 so far
#
# Step 229 / 500 [===============>-------------------] ETA  8s | 00:00:06 so far
#
# Step 230 / 500 [===============>-------------------] ETA  8s | 00:00:06 so far
#
# Step 231 / 500 [===============>-------------------] ETA  8s | 00:00:06 so far
#
# Step 232 / 500 [===============>-------------------] ETA  8s | 00:00:06 so far
#
# Step 233 / 500 [===============>-------------------] ETA  8s | 00:00:06 so far
#
# Step 234 / 500 [===============>-------------------] ETA  8s | 00:00:06 so far
#
# Step 235 / 500 [===============>-------------------] ETA  8s | 00:00:06 so far
#
# Step 236 / 500 [================>------------------] ETA  8s | 00:00:06 so far
#
# Step 237 / 500 [================>------------------] ETA  8s | 00:00:06 so far
#
# Step 238 / 500 [================>------------------] ETA  8s | 00:00:06 so far
#
# Step 239 / 500 [================>------------------] ETA  8s | 00:00:06 so far
#
# Step 240 / 500 [================>------------------] ETA  8s | 00:00:06 so far
#
# Step 241 / 500 [================>------------------] ETA  8s | 00:00:06 so far
#
# Step 242 / 500 [================>------------------] ETA  8s | 00:00:07 so far
#
# Step 243 / 500 [================>------------------] ETA  7s | 00:00:07 so far
#
# Step 244 / 500 [================>------------------] ETA  7s | 00:00:07 so far
#
# Step 245 / 500 [================>------------------] ETA  7s | 00:00:07 so far
#
# Step 246 / 500 [================>------------------] ETA  7s | 00:00:07 so far
#
# Step 247 / 500 [================>------------------] ETA  7s | 00:00:07 so far
#
# Step 248 / 500 [================>------------------] ETA  7s | 00:00:07 so far
#
# Step 249 / 500 [================>------------------] ETA  7s | 00:00:07 so far
#
# Step 250 / 500 [=================>-----------------] ETA  7s | 00:00:07 so far
#
# Step 251 / 500 [=================>-----------------] ETA  7s | 00:00:07 so far
#
# Step 252 / 500 [=================>-----------------] ETA  7s | 00:00:07 so far
#
# Step 253 / 500 [=================>-----------------] ETA  7s | 00:00:07 so far
#
# Step 254 / 500 [=================>-----------------] ETA  7s | 00:00:07 so far
#
# Step 255 / 500 [=================>-----------------] ETA  7s | 00:00:07 so far
#
# Step 256 / 500 [=================>-----------------] ETA  7s | 00:00:07 so far
#
# Step 257 / 500 [=================>-----------------] ETA  7s | 00:00:07 so far
#
# Step 258 / 500 [=================>-----------------] ETA  7s | 00:00:07 so far
#
# Step 259 / 500 [=================>-----------------] ETA  7s | 00:00:07 so far
#
# Step 260 / 500 [=================>-----------------] ETA  7s | 00:00:07 so far
#
# Step 261 / 500 [=================>-----------------] ETA  7s | 00:00:07 so far
#
# Step 262 / 500 [=================>-----------------] ETA  7s | 00:00:07 so far
#
# Step 263 / 500 [=================>-----------------] ETA  7s | 00:00:07 so far
#
# Step 264 / 500 [=================>-----------------] ETA  7s | 00:00:07 so far
#
# Step 265 / 500 [==================>----------------] ETA  7s | 00:00:07 so far
#
# Step 266 / 500 [==================>----------------] ETA  7s | 00:00:07 so far
#
# Step 267 / 500 [==================>----------------] ETA  7s | 00:00:07 so far
#
# Step 268 / 500 [==================>----------------] ETA  7s | 00:00:07 so far
#
# Step 269 / 500 [==================>----------------] ETA  7s | 00:00:07 so far
#
# Step 270 / 500 [==================>----------------] ETA  7s | 00:00:07 so far
#
# Step 271 / 500 [==================>----------------] ETA  7s | 00:00:07 so far
#
# Step 272 / 500 [==================>----------------] ETA  7s | 00:00:07 so far
#
# Step 273 / 500 [==================>----------------] ETA  7s | 00:00:07 so far
#
# Step 274 / 500 [==================>----------------] ETA  7s | 00:00:08 so far
#
# Step 275 / 500 [==================>----------------] ETA  7s | 00:00:08 so far
#
# Step 276 / 500 [==================>----------------] ETA  7s | 00:00:08 so far
#
# Step 277 / 500 [==================>----------------] ETA  7s | 00:00:08 so far
#
# Step 278 / 500 [==================>----------------] ETA  6s | 00:00:08 so far
#
# Step 279 / 500 [===================>---------------] ETA  6s | 00:00:08 so far
#
# Step 280 / 500 [===================>---------------] ETA  6s | 00:00:08 so far
#
# Step 281 / 500 [===================>---------------] ETA  6s | 00:00:08 so far
#
# Step 282 / 500 [===================>---------------] ETA  6s | 00:00:08 so far
#
# Step 283 / 500 [===================>---------------] ETA  6s | 00:00:08 so far
#
# Step 284 / 500 [===================>---------------] ETA  6s | 00:00:08 so far
#
# Step 285 / 500 [===================>---------------] ETA  6s | 00:00:08 so far
#
# Step 286 / 500 [===================>---------------] ETA  6s | 00:00:08 so far
#
# Step 287 / 500 [===================>---------------] ETA  6s | 00:00:08 so far
#
# Step 288 / 500 [===================>---------------] ETA  6s | 00:00:08 so far
#
# Step 289 / 500 [===================>---------------] ETA  6s | 00:00:08 so far
#
# Step 290 / 500 [===================>---------------] ETA  6s | 00:00:08 so far
#
# Step 291 / 500 [===================>---------------] ETA  6s | 00:00:08 so far
#
# Step 292 / 500 [===================>---------------] ETA  6s | 00:00:08 so far
#
# Step 293 / 500 [====================>--------------] ETA  6s | 00:00:08 so far
#
# Step 294 / 500 [====================>--------------] ETA  6s | 00:00:08 so far
#
# Step 295 / 500 [====================>--------------] ETA  6s | 00:00:08 so far
#
# Step 296 / 500 [====================>--------------] ETA  6s | 00:00:08 so far
#
# Step 297 / 500 [====================>--------------] ETA  6s | 00:00:08 so far
#
# Step 298 / 500 [====================>--------------] ETA  6s | 00:00:08 so far
#
# Step 299 / 500 [====================>--------------] ETA  6s | 00:00:08 so far
#
# Step 300 / 500 [====================>--------------] ETA  6s | 00:00:08 so far
#
# Step 301 / 500 [====================>--------------] ETA  6s | 00:00:08 so far
#
# Step 302 / 500 [====================>--------------] ETA  6s | 00:00:08 so far
#
# Step 303 / 500 [====================>--------------] ETA  6s | 00:00:08 so far
#
# Step 304 / 500 [====================>--------------] ETA  6s | 00:00:08 so far
#
# Step 305 / 500 [====================>--------------] ETA  6s | 00:00:08 so far
#
# Step 306 / 500 [====================>--------------] ETA  6s | 00:00:08 so far
#
# Step 307 / 500 [====================>--------------] ETA  6s | 00:00:08 so far
#
# Step 308 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 309 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 310 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 311 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 312 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 313 / 500 [=====================>-------------] ETA  5s | 00:00:09 so far
#
# Step 314 / 500 [=====================>-------------] ETA  5s | 00:00:09 so far
#
# Step 315 / 500 [=====================>-------------] ETA  5s | 00:00:09 so far
#
# Step 316 / 500 [=====================>-------------] ETA  5s | 00:00:09 so far
#
# Step 317 / 500 [=====================>-------------] ETA  5s | 00:00:09 so far
#
# Step 318 / 500 [=====================>-------------] ETA  5s | 00:00:09 so far
#
# Step 319 / 500 [=====================>-------------] ETA  5s | 00:00:09 so far
#
# Step 320 / 500 [=====================>-------------] ETA  5s | 00:00:09 so far
#
# Step 321 / 500 [=====================>-------------] ETA  5s | 00:00:09 so far
#
# Step 322 / 500 [======================>------------] ETA  5s | 00:00:09 so far
#
# Step 323 / 500 [======================>------------] ETA  5s | 00:00:09 so far
#
# Step 324 / 500 [======================>------------] ETA  5s | 00:00:09 so far
#
# Step 325 / 500 [======================>------------] ETA  5s | 00:00:09 so far
#
# Step 326 / 500 [======================>------------] ETA  5s | 00:00:09 so far
#
# Step 327 / 500 [======================>------------] ETA  5s | 00:00:09 so far
#
# Step 328 / 500 [======================>------------] ETA  5s | 00:00:09 so far
#
# Step 329 / 500 [======================>------------] ETA  5s | 00:00:09 so far
#
# Step 330 / 500 [======================>------------] ETA  5s | 00:00:09 so far
#
# Step 331 / 500 [======================>------------] ETA  5s | 00:00:09 so far
#
# Step 332 / 500 [======================>------------] ETA  5s | 00:00:09 so far
#
# Step 333 / 500 [======================>------------] ETA  5s | 00:00:09 so far
#
# Step 334 / 500 [======================>------------] ETA  5s | 00:00:09 so far
#
# Step 335 / 500 [======================>------------] ETA  5s | 00:00:09 so far
#
# Step 336 / 500 [=======================>-----------] ETA  5s | 00:00:09 so far
#
# Step 337 / 500 [=======================>-----------] ETA  5s | 00:00:09 so far
#
# Step 338 / 500 [=======================>-----------] ETA  5s | 00:00:09 so far
#
# Step 339 / 500 [=======================>-----------] ETA  5s | 00:00:09 so far
#
# Step 340 / 500 [=======================>-----------] ETA  5s | 00:00:09 so far
#
# Step 341 / 500 [=======================>-----------] ETA  5s | 00:00:09 so far
#
# Step 342 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 343 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 344 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 345 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 346 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 347 / 500 [=======================>-----------] ETA  4s | 00:00:10 so far
#
# Step 348 / 500 [=======================>-----------] ETA  4s | 00:00:10 so far
#
# Step 349 / 500 [=======================>-----------] ETA  4s | 00:00:10 so far
#
# Step 350 / 500 [=======================>-----------] ETA  4s | 00:00:10 so far
#
# Step 351 / 500 [========================>----------] ETA  4s | 00:00:10 so far
#
# Step 352 / 500 [========================>----------] ETA  4s | 00:00:10 so far
#
# Step 353 / 500 [========================>----------] ETA  4s | 00:00:10 so far
#
# Step 354 / 500 [========================>----------] ETA  4s | 00:00:10 so far
#
# Step 355 / 500 [========================>----------] ETA  4s | 00:00:10 so far
#
# Step 356 / 500 [========================>----------] ETA  4s | 00:00:10 so far
#
# Step 357 / 500 [========================>----------] ETA  4s | 00:00:10 so far
#
# Step 358 / 500 [========================>----------] ETA  4s | 00:00:10 so far
#
# Step 359 / 500 [========================>----------] ETA  4s | 00:00:10 so far
#
# Step 360 / 500 [========================>----------] ETA  4s | 00:00:10 so far
#
# Step 361 / 500 [========================>----------] ETA  4s | 00:00:10 so far
#
# Step 362 / 500 [========================>----------] ETA  4s | 00:00:10 so far
#
# Step 363 / 500 [========================>----------] ETA  4s | 00:00:10 so far
#
# Step 364 / 500 [========================>----------] ETA  4s | 00:00:10 so far
#
# Step 365 / 500 [=========================>---------] ETA  4s | 00:00:10 so far
#
# Step 366 / 500 [=========================>---------] ETA  4s | 00:00:10 so far
#
# Step 367 / 500 [=========================>---------] ETA  4s | 00:00:10 so far
#
# Step 368 / 500 [=========================>---------] ETA  4s | 00:00:10 so far
#
# Step 369 / 500 [=========================>---------] ETA  4s | 00:00:10 so far
#
# Step 370 / 500 [=========================>---------] ETA  4s | 00:00:10 so far
#
# Step 371 / 500 [=========================>---------] ETA  4s | 00:00:10 so far
#
# Step 372 / 500 [=========================>---------] ETA  4s | 00:00:10 so far
#
# Step 373 / 500 [=========================>---------] ETA  4s | 00:00:10 so far
#
# Step 374 / 500 [=========================>---------] ETA  4s | 00:00:10 so far
#
# Step 375 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 376 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 377 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 378 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 379 / 500 [==========================>--------] ETA  4s | 00:00:11 so far
#
# Step 380 / 500 [==========================>--------] ETA  4s | 00:00:11 so far
#
# Step 381 / 500 [==========================>--------] ETA  3s | 00:00:11 so far
#
# Step 382 / 500 [==========================>--------] ETA  3s | 00:00:11 so far
#
# Step 383 / 500 [==========================>--------] ETA  3s | 00:00:11 so far
#
# Step 384 / 500 [==========================>--------] ETA  3s | 00:00:11 so far
#
# Step 385 / 500 [==========================>--------] ETA  3s | 00:00:11 so far
#
# Step 386 / 500 [==========================>--------] ETA  3s | 00:00:11 so far
#
# Step 387 / 500 [==========================>--------] ETA  3s | 00:00:11 so far
#
# Step 388 / 500 [==========================>--------] ETA  3s | 00:00:11 so far
#
# Step 389 / 500 [==========================>--------] ETA  3s | 00:00:11 so far
#
# Step 390 / 500 [==========================>--------] ETA  3s | 00:00:11 so far
#
# Step 391 / 500 [==========================>--------] ETA  3s | 00:00:11 so far
#
# Step 392 / 500 [==========================>--------] ETA  3s | 00:00:11 so far
#
# Step 393 / 500 [===========================>-------] ETA  3s | 00:00:11 so far
#
# Step 394 / 500 [===========================>-------] ETA  3s | 00:00:11 so far
#
# Step 395 / 500 [===========================>-------] ETA  3s | 00:00:11 so far
#
# Step 396 / 500 [===========================>-------] ETA  3s | 00:00:11 so far
#
# Step 397 / 500 [===========================>-------] ETA  3s | 00:00:11 so far
#
# Step 398 / 500 [===========================>-------] ETA  3s | 00:00:11 so far
#
# Step 399 / 500 [===========================>-------] ETA  3s | 00:00:11 so far
#
# Step 400 / 500 [===========================>-------] ETA  3s | 00:00:11 so far
#
# Step 401 / 500 [===========================>-------] ETA  3s | 00:00:11 so far
#
# Step 402 / 500 [===========================>-------] ETA  3s | 00:00:11 so far
#
# Step 403 / 500 [===========================>-------] ETA  3s | 00:00:11 so far
#
# Step 404 / 500 [===========================>-------] ETA  3s | 00:00:11 so far
#
# Step 405 / 500 [===========================>-------] ETA  3s | 00:00:11 so far
#
# Step 406 / 500 [===========================>-------] ETA  3s | 00:00:11 so far
#
# Step 407 / 500 [===========================>-------] ETA  3s | 00:00:11 so far
#
# Step 408 / 500 [============================>------] ETA  3s | 00:00:11 so far
#
# Step 409 / 500 [============================>------] ETA  3s | 00:00:11 so far
#
# Step 410 / 500 [============================>------] ETA  3s | 00:00:12 so far
#
# Step 411 / 500 [============================>------] ETA  3s | 00:00:12 so far
#
# Step 412 / 500 [============================>------] ETA  3s | 00:00:12 so far
#
# Step 413 / 500 [============================>------] ETA  3s | 00:00:12 so far
#
# Step 414 / 500 [============================>------] ETA  3s | 00:00:12 so far
#
# Step 415 / 500 [============================>------] ETA  2s | 00:00:12 so far
#
# Step 416 / 500 [============================>------] ETA  2s | 00:00:12 so far
#
# Step 417 / 500 [============================>------] ETA  2s | 00:00:12 so far
#
# Step 418 / 500 [============================>------] ETA  2s | 00:00:12 so far
#
# Step 419 / 500 [============================>------] ETA  2s | 00:00:12 so far
#
# Step 420 / 500 [============================>------] ETA  2s | 00:00:12 so far
#
# Step 421 / 500 [============================>------] ETA  2s | 00:00:12 so far
#
# Step 422 / 500 [=============================>-----] ETA  2s | 00:00:12 so far
#
# Step 423 / 500 [=============================>-----] ETA  2s | 00:00:12 so far
#
# Step 424 / 500 [=============================>-----] ETA  2s | 00:00:12 so far
#
# Step 425 / 500 [=============================>-----] ETA  2s | 00:00:12 so far
#
# Step 426 / 500 [=============================>-----] ETA  2s | 00:00:12 so far
#
# Step 427 / 500 [=============================>-----] ETA  2s | 00:00:12 so far
#
# Step 428 / 500 [=============================>-----] ETA  2s | 00:00:12 so far
#
# Step 429 / 500 [=============================>-----] ETA  2s | 00:00:12 so far
#
# Step 430 / 500 [=============================>-----] ETA  2s | 00:00:12 so far
#
# Step 431 / 500 [=============================>-----] ETA  2s | 00:00:12 so far
#
# Step 432 / 500 [=============================>-----] ETA  2s | 00:00:12 so far
#
# Step 433 / 500 [=============================>-----] ETA  2s | 00:00:12 so far
#
# Step 434 / 500 [=============================>-----] ETA  2s | 00:00:12 so far
#
# Step 435 / 500 [=============================>-----] ETA  2s | 00:00:12 so far
#
# Step 436 / 500 [==============================>----] ETA  2s | 00:00:12 so far
#
# Step 437 / 500 [==============================>----] ETA  2s | 00:00:12 so far
#
# Step 438 / 500 [==============================>----] ETA  2s | 00:00:12 so far
#
# Step 439 / 500 [==============================>----] ETA  2s | 00:00:12 so far
#
# Step 440 / 500 [==============================>----] ETA  2s | 00:00:12 so far
#
# Step 441 / 500 [==============================>----] ETA  2s | 00:00:12 so far
#
# Step 442 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 443 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 444 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 445 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 446 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 447 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 448 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 449 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 450 / 500 [===============================>---] ETA  1s | 00:00:13 so far
#
# Step 451 / 500 [===============================>---] ETA  1s | 00:00:13 so far
#
# Step 452 / 500 [===============================>---] ETA  1s | 00:00:13 so far
#
# Step 453 / 500 [===============================>---] ETA  1s | 00:00:13 so far
#
# Step 454 / 500 [===============================>---] ETA  1s | 00:00:13 so far
#
# Step 455 / 500 [===============================>---] ETA  1s | 00:00:13 so far
#
# Step 456 / 500 [===============================>---] ETA  1s | 00:00:13 so far
#
# Step 457 / 500 [===============================>---] ETA  1s | 00:00:13 so far
#
# Step 458 / 500 [===============================>---] ETA  1s | 00:00:13 so far
#
# Step 459 / 500 [===============================>---] ETA  1s | 00:00:13 so far
#
# Step 460 / 500 [===============================>---] ETA  1s | 00:00:13 so far
#
# Step 461 / 500 [===============================>---] ETA  1s | 00:00:13 so far
#
# Step 462 / 500 [===============================>---] ETA  1s | 00:00:13 so far
#
# Step 463 / 500 [===============================>---] ETA  1s | 00:00:13 so far
#
# Step 464 / 500 [===============================>---] ETA  1s | 00:00:13 so far
#
# Step 465 / 500 [================================>--] ETA  1s | 00:00:13 so far
#
# Step 466 / 500 [================================>--] ETA  1s | 00:00:13 so far
#
# Step 467 / 500 [================================>--] ETA  1s | 00:00:13 so far
#
# Step 468 / 500 [================================>--] ETA  1s | 00:00:13 so far
#
# Step 469 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 470 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 471 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 472 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 473 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 474 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 475 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 476 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 477 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 478 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 479 / 500 [=================================>-] ETA  1s | 00:00:14 so far
#
# Step 480 / 500 [=================================>-] ETA  1s | 00:00:14 so far
#
# Step 481 / 500 [=================================>-] ETA  1s | 00:00:14 so far
#
# Step 482 / 500 [=================================>-] ETA  1s | 00:00:14 so far
#
# Step 483 / 500 [=================================>-] ETA  1s | 00:00:14 so far
#
# Step 484 / 500 [=================================>-] ETA  0s | 00:00:14 so far
#
# Step 485 / 500 [=================================>-] ETA  0s | 00:00:14 so far
#
# Step 486 / 500 [=================================>-] ETA  0s | 00:00:14 so far
#
# Step 487 / 500 [=================================>-] ETA  0s | 00:00:14 so far
#
# Step 488 / 500 [=================================>-] ETA  0s | 00:00:14 so far
#
# Step 489 / 500 [=================================>-] ETA  0s | 00:00:14 so far
#
# Step 490 / 500 [=================================>-] ETA  0s | 00:00:14 so far
#
# Step 491 / 500 [=================================>-] ETA  0s | 00:00:14 so far
#
# Step 492 / 500 [=================================>-] ETA  0s | 00:00:14 so far
#
# Step 493 / 500 [==================================>] ETA  0s | 00:00:14 so far
#
# Step 494 / 500 [==================================>] ETA  0s | 00:00:14 so far
#
# Step 495 / 500 [==================================>] ETA  0s | 00:00:14 so far
#
# Step 496 / 500 [==================================>] ETA  0s | 00:00:14 so far
#
# Step 497 / 500 [==================================>] ETA  0s | 00:00:14 so far
#
# Step 498 / 500 [==================================>] ETA  0s | 00:00:14 so far
#
# Step 499 / 500 [==================================>] ETA  0s | 00:00:14 so far
#
# Step 500 / 500 [===================================] ETA  0s | 00:00:14 so far
#
#
# Finished 500 steps in 15 secs
#
# Running chain 2 / 4
#
#
# Step 22 / 500 [=>----------------------------------] ETA  5s | 00:00:00 so far
#
# Step 23 / 500 [=>----------------------------------] ETA  5s | 00:00:00 so far
#
# Step 24 / 500 [=>----------------------------------] ETA  5s | 00:00:00 so far
#
# Step 25 / 500 [=>----------------------------------] ETA  6s | 00:00:00 so far
#
# Step 26 / 500 [=>----------------------------------] ETA  6s | 00:00:00 so far
#
# Step 27 / 500 [=>----------------------------------] ETA  6s | 00:00:00 so far
#
# Step 28 / 500 [=>----------------------------------] ETA  7s | 00:00:00 so far
#
# Step 29 / 500 [=>----------------------------------] ETA  7s | 00:00:00 so far
#
# Step 30 / 500 [=>----------------------------------] ETA  7s | 00:00:00 so far
#
# Step 31 / 500 [=>----------------------------------] ETA  7s | 00:00:00 so far
#
# Step 32 / 500 [=>----------------------------------] ETA  7s | 00:00:00 so far
#
# Step 33 / 500 [=>----------------------------------] ETA  8s | 00:00:00 so far
#
# Step 34 / 500 [=>----------------------------------] ETA  8s | 00:00:00 so far
#
# Step 35 / 500 [==>---------------------------------] ETA  8s | 00:00:00 so far
#
# Step 36 / 500 [==>---------------------------------] ETA  8s | 00:00:00 so far
#
# Step 37 / 500 [==>---------------------------------] ETA  8s | 00:00:00 so far
#
# Step 38 / 500 [==>---------------------------------] ETA  9s | 00:00:00 so far
#
# Step 39 / 500 [==>---------------------------------] ETA  9s | 00:00:00 so far
#
# Step 40 / 500 [==>---------------------------------] ETA  9s | 00:00:00 so far
#
# Step 41 / 500 [==>---------------------------------] ETA  9s | 00:00:00 so far
#
# Step 42 / 500 [==>---------------------------------] ETA  9s | 00:00:00 so far
#
# Step 43 / 500 [==>---------------------------------] ETA  9s | 00:00:00 so far
#
# Step 44 / 500 [==>---------------------------------] ETA  9s | 00:00:00 so far
#
# Step 45 / 500 [==>---------------------------------] ETA  9s | 00:00:00 so far
#
# Step 46 / 500 [==>---------------------------------] ETA  9s | 00:00:00 so far
#
# Step 47 / 500 [==>---------------------------------] ETA  9s | 00:00:00 so far
#
# Step 48 / 500 [==>---------------------------------] ETA  9s | 00:00:00 so far
#
# Step 49 / 500 [===>--------------------------------] ETA  9s | 00:00:01 so far
#
# Step 50 / 500 [===>--------------------------------] ETA  9s | 00:00:01 so far
#
# Step 51 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 52 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 53 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 54 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 55 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 56 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 57 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 58 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 59 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 60 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 61 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 62 / 500 [===>--------------------------------] ETA 10s | 00:00:01 so far
#
# Step 63 / 500 [====>-------------------------------] ETA 10s | 00:00:01 so far
#
# Step 64 / 500 [====>-------------------------------] ETA 10s | 00:00:01 so far
#
# Step 65 / 500 [====>-------------------------------] ETA 10s | 00:00:01 so far
#
# Step 66 / 500 [====>-------------------------------] ETA 10s | 00:00:01 so far
#
# Step 67 / 500 [====>-------------------------------] ETA 10s | 00:00:01 so far
#
# Step 68 / 500 [====>-------------------------------] ETA 10s | 00:00:01 so far
#
# Step 69 / 500 [====>-------------------------------] ETA 10s | 00:00:01 so far
#
# Step 70 / 500 [====>-------------------------------] ETA 10s | 00:00:01 so far
#
# Step 71 / 500 [====>-------------------------------] ETA 10s | 00:00:01 so far
#
# Step 72 / 500 [====>-------------------------------] ETA 10s | 00:00:01 so far
#
# Step 73 / 500 [====>-------------------------------] ETA 10s | 00:00:01 so far
#
# Step 74 / 500 [====>-------------------------------] ETA 10s | 00:00:01 so far
#
# Step 75 / 500 [====>-------------------------------] ETA 10s | 00:00:01 so far
#
# Step 76 / 500 [====>-------------------------------] ETA 10s | 00:00:01 so far
#
# Step 77 / 500 [=====>------------------------------] ETA 10s | 00:00:01 so far
#
# Step 78 / 500 [=====>------------------------------] ETA 10s | 00:00:01 so far
#
# Step 79 / 500 [=====>------------------------------] ETA 10s | 00:00:01 so far
#
# Step 80 / 500 [=====>------------------------------] ETA 10s | 00:00:01 so far
#
# Step 81 / 500 [=====>------------------------------] ETA 10s | 00:00:01 so far
#
# Step 82 / 500 [=====>------------------------------] ETA 10s | 00:00:01 so far
#
# Step 83 / 500 [=====>------------------------------] ETA 10s | 00:00:02 so far
#
# Step 84 / 500 [=====>------------------------------] ETA 10s | 00:00:02 so far
#
# Step 85 / 500 [=====>------------------------------] ETA 10s | 00:00:02 so far
#
# Step 86 / 500 [=====>------------------------------] ETA 10s | 00:00:02 so far
#
# Step 87 / 500 [=====>------------------------------] ETA 10s | 00:00:02 so far
#
# Step 88 / 500 [=====>------------------------------] ETA 10s | 00:00:02 so far
#
# Step 89 / 500 [=====>------------------------------] ETA 10s | 00:00:02 so far
#
# Step 90 / 500 [=====>------------------------------] ETA 10s | 00:00:02 so far
#
# Step 91 / 500 [======>-----------------------------] ETA 10s | 00:00:02 so far
#
# Step 92 / 500 [======>-----------------------------] ETA 10s | 00:00:02 so far
#
# Step 93 / 500 [======>-----------------------------] ETA 10s | 00:00:02 so far
#
# Step 94 / 500 [======>-----------------------------] ETA 10s | 00:00:02 so far
#
# Step 95 / 500 [======>-----------------------------] ETA 10s | 00:00:02 so far
#
# Step 96 / 500 [======>-----------------------------] ETA 10s | 00:00:02 so far
#
# Step 97 / 500 [======>-----------------------------] ETA 10s | 00:00:02 so far
#
# Step 98 / 500 [======>-----------------------------] ETA 10s | 00:00:02 so far
#
# Step 99 / 500 [======>-----------------------------] ETA 10s | 00:00:02 so far
#
# Step 100 / 500 [======>----------------------------] ETA 10s | 00:00:02 so far
#
# Step 101 / 500 [======>----------------------------] ETA 10s | 00:00:02 so far
#
# Step 102 / 500 [======>----------------------------] ETA 10s | 00:00:02 so far
#
# Step 103 / 500 [======>----------------------------] ETA 10s | 00:00:02 so far
#
# Step 104 / 500 [======>----------------------------] ETA 10s | 00:00:02 so far
#
# Step 105 / 500 [======>----------------------------] ETA 10s | 00:00:02 so far
#
# Step 106 / 500 [======>----------------------------] ETA 10s | 00:00:02 so far
#
# Step 107 / 500 [======>----------------------------] ETA 10s | 00:00:02 so far
#
# Step 108 / 500 [=======>---------------------------] ETA 10s | 00:00:02 so far
#
# Step 109 / 500 [=======>---------------------------] ETA 10s | 00:00:02 so far
#
# Step 110 / 500 [=======>---------------------------] ETA 10s | 00:00:02 so far
#
# Step 111 / 500 [=======>---------------------------] ETA 10s | 00:00:02 so far
#
# Step 112 / 500 [=======>---------------------------] ETA 10s | 00:00:02 so far
#
# Step 113 / 500 [=======>---------------------------] ETA 10s | 00:00:02 so far
#
# Step 114 / 500 [=======>---------------------------] ETA 10s | 00:00:02 so far
#
# Step 115 / 500 [=======>---------------------------] ETA 10s | 00:00:02 so far
#
# Step 116 / 500 [=======>---------------------------] ETA 10s | 00:00:02 so far
#
# Step 117 / 500 [=======>---------------------------] ETA 10s | 00:00:03 so far
#
# Step 118 / 500 [=======>---------------------------] ETA 10s | 00:00:03 so far
#
# Step 119 / 500 [=======>---------------------------] ETA 10s | 00:00:03 so far
#
# Step 120 / 500 [=======>---------------------------] ETA 10s | 00:00:03 so far
#
# Step 121 / 500 [=======>---------------------------] ETA 10s | 00:00:03 so far
#
# Step 122 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 123 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 124 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 125 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 126 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 127 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 128 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 129 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 130 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 131 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 132 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 133 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 134 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 135 / 500 [========>--------------------------] ETA 10s | 00:00:03 so far
#
# Step 136 / 500 [=========>-------------------------] ETA 10s | 00:00:03 so far
#
# Step 137 / 500 [=========>-------------------------] ETA 10s | 00:00:03 so far
#
# Step 138 / 500 [=========>-------------------------] ETA 10s | 00:00:03 so far
#
# ...
#
# Step 303 / 500 [====================>--------------] ETA  6s | 00:00:09 so far
#
# Step 304 / 500 [====================>--------------] ETA  6s | 00:00:09 so far
#
# Step 305 / 500 [====================>--------------] ETA  6s | 00:00:09 so far
#
# Step 306 / 500 [====================>--------------] ETA  6s | 00:00:09 so far
#
# Step 307 / 500 [====================>--------------] ETA  6s | 00:00:09 so far
#
# Step 308 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 309 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 310 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 311 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 312 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 313 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 314 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 315 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 316 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 317 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 318 / 500 [=====================>-------------] ETA  6s | 00:00:09 so far
#
# Step 319 / 500 [=====================>-------------] ETA  6s | 00:00:10 so far
#
# Step 320 / 500 [=====================>-------------] ETA  6s | 00:00:10 so far
#
# Step 321 / 500 [=====================>-------------] ETA  6s | 00:00:10 so far
#
# Step 322 / 500 [======================>------------] ETA  6s | 00:00:10 so far
#
# Step 323 / 500 [======================>------------] ETA  6s | 00:00:10 so far
#
# Step 324 / 500 [======================>------------] ETA  6s | 00:00:10 so far
#
# Step 325 / 500 [======================>------------] ETA  6s | 00:00:10 so far
#
# Step 326 / 500 [======================>------------] ETA  5s | 00:00:10 so far
#
# Step 327 / 500 [======================>------------] ETA  5s | 00:00:10 so far
#
# Step 328 / 500 [======================>------------] ETA  5s | 00:00:10 so far
#
# Step 329 / 500 [======================>------------] ETA  5s | 00:00:10 so far
#
# Step 330 / 500 [======================>------------] ETA  5s | 00:00:10 so far
#
# Step 331 / 500 [======================>------------] ETA  5s | 00:00:10 so far
#
# Step 332 / 500 [======================>------------] ETA  5s | 00:00:10 so far
#
# Step 333 / 500 [======================>------------] ETA  5s | 00:00:10 so far
#
# Step 334 / 500 [======================>------------] ETA  5s | 00:00:10 so far
#
# Step 335 / 500 [======================>------------] ETA  5s | 00:00:10 so far
#
# Step 336 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 337 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 338 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 339 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 340 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 341 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 342 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 343 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 344 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 345 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 346 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 347 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 348 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 349 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 350 / 500 [=======================>-----------] ETA  5s | 00:00:10 so far
#
# Step 351 / 500 [========================>----------] ETA  5s | 00:00:11 so far
#
# Step 352 / 500 [========================>----------] ETA  5s | 00:00:11 so far
#
# Step 353 / 500 [========================>----------] ETA  5s | 00:00:11 so far
#
# Step 354 / 500 [========================>----------] ETA  5s | 00:00:11 so far
#
# Step 355 / 500 [========================>----------] ETA  5s | 00:00:11 so far
#
# Step 356 / 500 [========================>----------] ETA  5s | 00:00:11 so far
#
# Step 357 / 500 [========================>----------] ETA  4s | 00:00:11 so far
#
# Step 358 / 500 [========================>----------] ETA  4s | 00:00:11 so far
#
# Step 359 / 500 [========================>----------] ETA  4s | 00:00:11 so far
#
# Step 360 / 500 [========================>----------] ETA  4s | 00:00:11 so far
#
# Step 361 / 500 [========================>----------] ETA  4s | 00:00:11 so far
#
# Step 362 / 500 [========================>----------] ETA  4s | 00:00:11 so far
#
# Step 363 / 500 [========================>----------] ETA  4s | 00:00:11 so far
#
# Step 364 / 500 [========================>----------] ETA  4s | 00:00:11 so far
#
# Step 365 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 366 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 367 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 368 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 369 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 370 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 371 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 372 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 373 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 374 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 375 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 376 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 377 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 378 / 500 [=========================>---------] ETA  4s | 00:00:11 so far
#
# Step 379 / 500 [==========================>--------] ETA  4s | 00:00:11 so far
#
# Step 380 / 500 [==========================>--------] ETA  4s | 00:00:11 so far
#
# Step 381 / 500 [==========================>--------] ETA  4s | 00:00:11 so far
#
# Step 382 / 500 [==========================>--------] ETA  4s | 00:00:12 so far
#
# Step 383 / 500 [==========================>--------] ETA  4s | 00:00:12 so far
#
# Step 384 / 500 [==========================>--------] ETA  4s | 00:00:12 so far
#
# Step 385 / 500 [==========================>--------] ETA  4s | 00:00:12 so far
#
# Step 386 / 500 [==========================>--------] ETA  4s | 00:00:12 so far
#
# Step 387 / 500 [==========================>--------] ETA  4s | 00:00:12 so far
#
# Step 388 / 500 [==========================>--------] ETA  4s | 00:00:12 so far
#
# Step 389 / 500 [==========================>--------] ETA  3s | 00:00:12 so far
#
# Step 390 / 500 [==========================>--------] ETA  3s | 00:00:12 so far
#
# Step 391 / 500 [==========================>--------] ETA  3s | 00:00:12 so far
#
# Step 392 / 500 [==========================>--------] ETA  3s | 00:00:12 so far
#
# Step 393 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 394 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 395 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 396 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 397 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 398 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 399 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 400 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 401 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 402 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 403 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 404 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 405 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 406 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 407 / 500 [===========================>-------] ETA  3s | 00:00:12 so far
#
# Step 408 / 500 [============================>------] ETA  3s | 00:00:12 so far
#
# Step 409 / 500 [============================>------] ETA  3s | 00:00:12 so far
#
# Step 410 / 500 [============================>------] ETA  3s | 00:00:12 so far
#
# Step 411 / 500 [============================>------] ETA  3s | 00:00:12 so far
#
# Step 412 / 500 [============================>------] ETA  3s | 00:00:12 so far
#
# Step 413 / 500 [============================>------] ETA  3s | 00:00:13 so far
#
# Step 414 / 500 [============================>------] ETA  3s | 00:00:13 so far
#
# Step 415 / 500 [============================>------] ETA  3s | 00:00:13 so far
#
# Step 416 / 500 [============================>------] ETA  3s | 00:00:13 so far
#
# Step 417 / 500 [============================>------] ETA  3s | 00:00:13 so far
#
# Step 418 / 500 [============================>------] ETA  3s | 00:00:13 so far
#
# Step 419 / 500 [============================>------] ETA  3s | 00:00:13 so far
#
# Step 420 / 500 [============================>------] ETA  3s | 00:00:13 so far
#
# Step 421 / 500 [============================>------] ETA  2s | 00:00:13 so far
#
# Step 422 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 423 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 424 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 425 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 426 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 427 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 428 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 429 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 430 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 431 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 432 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 433 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 434 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 435 / 500 [=============================>-----] ETA  2s | 00:00:13 so far
#
# Step 436 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 437 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 438 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 439 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 440 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 441 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 442 / 500 [==============================>----] ETA  2s | 00:00:13 so far
#
# Step 443 / 500 [==============================>----] ETA  2s | 00:00:14 so far
#
# Step 444 / 500 [==============================>----] ETA  2s | 00:00:14 so far
#
# Step 445 / 500 [==============================>----] ETA  2s | 00:00:14 so far
#
# Step 446 / 500 [==============================>----] ETA  2s | 00:00:14 so far
#
# Step 447 / 500 [==============================>----] ETA  2s | 00:00:14 so far
#
# Step 448 / 500 [==============================>----] ETA  2s | 00:00:14 so far
#
# Step 449 / 500 [==============================>----] ETA  2s | 00:00:14 so far
#
# Step 450 / 500 [===============================>---] ETA  2s | 00:00:14 so far
#
# Step 451 / 500 [===============================>---] ETA  2s | 00:00:14 so far
#
# Step 452 / 500 [===============================>---] ETA  2s | 00:00:14 so far
#
# Step 453 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 454 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 455 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 456 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 457 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 458 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 459 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 460 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 461 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 462 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 463 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 464 / 500 [===============================>---] ETA  1s | 00:00:14 so far
#
# Step 465 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 466 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 467 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 468 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 469 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 470 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 471 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 472 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 473 / 500 [================================>--] ETA  1s | 00:00:14 so far
#
# Step 474 / 500 [================================>--] ETA  1s | 00:00:15 so far
#
# Step 475 / 500 [================================>--] ETA  1s | 00:00:15 so far
#
# Step 476 / 500 [================================>--] ETA  1s | 00:00:15 so far
#
# Step 477 / 500 [================================>--] ETA  1s | 00:00:15 so far
#
# Step 478 / 500 [================================>--] ETA  1s | 00:00:15 so far
#
# Step 479 / 500 [=================================>-] ETA  1s | 00:00:15 so far
#
# Step 480 / 500 [=================================>-] ETA  1s | 00:00:15 so far
#
# Step 481 / 500 [=================================>-] ETA  1s | 00:00:15 so far
#
# Step 482 / 500 [=================================>-] ETA  1s | 00:00:15 so far
#
# Step 483 / 500 [=================================>-] ETA  1s | 00:00:15 so far
#
# Step 484 / 500 [=================================>-] ETA  1s | 00:00:15 so far
#
# Step 485 / 500 [=================================>-] ETA  0s | 00:00:15 so far
#
# Step 486 / 500 [=================================>-] ETA  0s | 00:00:15 so far
#
# Step 487 / 500 [=================================>-] ETA  0s | 00:00:15 so far
#
# Step 488 / 500 [=================================>-] ETA  0s | 00:00:15 so far
#
# Step 489 / 500 [=================================>-] ETA  0s | 00:00:15 so far
#
# Step 490 / 500 [=================================>-] ETA  0s | 00:00:15 so far
#
# Step 491 / 500 [=================================>-] ETA  0s | 00:00:15 so far
#
# Step 492 / 500 [=================================>-] ETA  0s | 00:00:15 so far
#
# Step 493 / 500 [==================================>] ETA  0s | 00:00:15 so far
#
# Step 494 / 500 [==================================>] ETA  0s | 00:00:15 so far
#
# Step 495 / 500 [==================================>] ETA  0s | 00:00:15 so far
#
# Step 496 / 500 [==================================>] ETA  0s | 00:00:15 so far
#
# Step 497 / 500 [==================================>] ETA  0s | 00:00:15 so far
#
# Step 498 / 500 [==================================>] ETA  0s | 00:00:15 so far
#
# Step 499 / 500 [==================================>] ETA  0s | 00:00:15 so far
#
# Step 500 / 500 [===================================] ETA  0s | 00:00:15 so far
#
#
# Finished 500 steps in 16 secs

# %%
install.packages('coda')
# Out:
# Installing package into 'C:/Users/julia/OneDrive - London School of Hygiene and Tropical Medicine/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# package 'coda' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\julia\AppData\Local\Temp\RtmpIR1QDA\downloaded_packages

# %%
mcmc2 <- coda::as.mcmc(cbind(
  pmcmc_tuned_run$probabilities, pmcmc_tuned_run$pars))

summary(mcmc2)
# Out:
# Iterations = 1:2000
# Thinning interval = 1
# Number of chains = 1
# Sample size per chain = 2000
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#                      Mean        SD  Naive SE Time-series SE
# log_prior      -9.917e-01    0.5007 1.120e-02        0.10275
# log_likelihood -1.039e+05 5478.5393 1.225e+02      509.17062
# log_posterior  -1.039e+05 5478.2722 1.225e+02      509.14169
# beta            9.734e-01    0.1463 3.271e-03        0.02503
# gamma           5.202e-01    0.1001 2.239e-03        0.02055
#
# 2. Quantiles for each variable:
#
#                      2.5%        25%        50%        75%      97.5%
# log_prior      -1.725e+00 -1.309e+00 -7.863e-01 -7.403e-01  2.034e-01
# log_likelihood -1.146e+05 -1.031e+05 -1.029e+05 -1.026e+05 -1.026e+05
# log_posterior  -1.146e+05 -1.031e+05 -1.029e+05 -1.026e+05 -1.026e+05
# beta            5.160e-01  8.870e-01  9.837e-01  1.062e+00  1.109e+00
# gamma           2.812e-01  4.700e-01  4.792e-01  5.836e-01  6.669e-01

# %%
plot(mcmc2)
# Out:
# Plot with title "Density of log_posterior"
# Plot with title "Density of gamma"

# %% [markdown]
# **Running predictions**

# %%
forecast <- predict(processed_chains,
                    steps = seq(400, 800, 4),
                    prepend_trajectories = TRUE,
                    seed = processed_chains$predict$seed)

keep <- sample.int(ncol(forecast$state), size = 10)
mini_forecast <- forecast$state[, keep, ]

plot_particle_filter(mini_forecast,
                     true_history,
                     seq_len(20),
                     obs_end = max(incidence$day))
# Out:
# Error in pmcmc_predict(object, ...): Expected steps[1] to be 76
# Traceback:
#
# 1. predict(processed_chains, steps = seq(400, 800, 4), prepend_trajectories = TRUE,
#  .     seed = processed_chains$predict$seed)
# 2. predict.mcstate_pmcmc(processed_chains, steps = seq(400, 800,
#  .     4), prepend_trajectories = TRUE, seed = processed_chains$predict$seed)
# 3. pmcmc_predict(object, ...)
# 4. stop(sprintf("Expected steps[1] to be %d", object$predict$step))
